# %%
import pathlib

import optuna
import pandas as pd
import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sqlalchemy import create_engine
from xgboost import XGBClassifier

from utils.config import load_config
from utils.data import initialize_project

config_path = pathlib.Path.cwd().parent / "config.yaml"
config = load_config(config_path)
sklearn.set_config(transform_output="pandas")

db_uri = initialize_project(config=config, init_db=False)
engine = create_engine(db_uri)
# Out:
# Config loaded from /Users/haukesteffen/dev/TabularShenanigans/config.yaml.

# %%
with engine.begin() as connection:
    train = (
        pd.read_sql(
            sql=f"SELECT * FROM [{config.competition_name}-train-preprocessed]",
            con=connection,
        )
        .convert_dtypes()
        .sample(frac=1.0)
    )
    test = (
        pd.read_sql(
            sql=f"SELECT * FROM [{config.competition_name}-test-preprocessed]",
            con=connection,
        )
        .convert_dtypes()
        .sample(frac=1.0)
    )

train = train.set_index(config.id_column)
X_train = train.drop(columns=[config.target_column])
y_train = train[config.target_column]

test = test.set_index(config.id_column)
X_test = test

X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.1, random_state=42
)

# %%
model_configs = [
    {
        "name": "XGBoost",
        "model": XGBClassifier,
        "params": lambda trial: {
            "n_estimators": trial.suggest_int("n_estimators", 200, 1000),
            "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
            "max_depth": trial.suggest_int("max_depth", 3, 9),
            "subsample": trial.suggest_float("subsample", 0.5, 1.0),
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
            "gamma": trial.suggest_float("gamma", 0, 5),
            "eval_metric": "logloss",
            "random_state": 42,
            "n_jobs": -1,
        },
    },
    {
        "name": "KNeighbors",
        "model": KNeighborsClassifier,
        "params": lambda trial: {
            "n_neighbors": trial.suggest_int("n_neighbors", 3, 30),
            "weights": trial.suggest_categorical("weights", ["uniform", "distance"]),
            "p": trial.suggest_int("p", 1, 2),
            "n_jobs": -1,
        },
    },
    {
        "name": "SVC",
        "model": SVC,
        "params": lambda trial: {
            "C": trial.suggest_float("C", 1e-4, 1e3, log=True),
            "gamma": trial.suggest_float("gamma", 1e-4, 1e2, log=True),
            "kernel": "rbf",
            "probability": True,
            "random_state": 42,
        },
    },
    {
        "name": "MLPClassifier",
        "model": MLPClassifier,
        "params": lambda trial: {
            "hidden_layer_sizes": (trial.suggest_int("n_units", 50, 200),),
            "activation": trial.suggest_categorical("activation", ["relu", "tanh"]),
            "alpha": trial.suggest_float("alpha", 1e-5, 1e-1, log=True),
            "learning_rate_init": trial.suggest_float(
                "learning_rate_init", 1e-4, 1e-2, log=True
            ),
            "max_iter": 1000,
            "random_state": 42,
        },
    },
    {
        "name": "GaussianNB",
        "model": GaussianNB,
        "params": lambda trial: {
            # No hyperparameters to tune or execution parameters to set.
        },
    },
    {
        "name": "LogisticRegression",
        "model": LogisticRegression,
        "params": lambda trial: {
            "solver": "liblinear",
            "penalty": trial.suggest_categorical("penalty", ["l1", "l2"]),
            "C": trial.suggest_float("C", 1e-4, 1e2, log=True),
            "max_iter": 2000,
            "random_state": 42,
        },
    },
]

# %%
def tune_model(model_config, storage_location, X_train, y_train):
    """
    A generic function to run an Optuna study for any given model configuration,
    saving the results to the specified storage.
    """
    model_class = model_config["model"]
    param_lambda = model_config["params"]
    study_name = f"study-{model_config['name']}"  # e.g., "study-XGBoost"

    def objective(trial):
        params = param_lambda(trial)
        model = model_class(**params)
        score = cross_val_score(
            model, X_train, y_train, scoring="roc_auc", cv=5, n_jobs=1
        )
        return score.mean()

    # ** THE CHANGE IS HERE **
    study = optuna.create_study(
        direction="maximize",
        sampler=optuna.samplers.TPESampler(seed=42),
        storage=storage_location,  # Tells Optuna where to save the study
        study_name=study_name,  # The unique name for this model's study
        load_if_exists=True,  # The magic flag to resume the study
    )

    # We can check if the study is already finished
    if len(study.trials) >= 50:  # The n_trials we want to run
        print(f"Study '{study_name}' already completed. Skipping.")
    else:
        remaining_trials = 50 - len(study.trials)
        print(f"Resuming study '{study_name}'. {remaining_trials} trials left to run.")
        study.optimize(objective, n_trials=remaining_trials)

    return study.best_trial


# --- 4. Run the Tuning for All Models ---
storage_db = "sqlite:///optuna.db"

best_models = []
for config in model_configs:
    print(f"--- Tuning {config['name']} ---")
    # ** NEW: Pass the storage location to the function **
    best_trial = tune_model(config, storage_db, X_train, y_train)

    best_models.append(
        {
            "name": config["name"],
            "best_score_cv": best_trial.value,
            "best_params": best_trial.params,
            "model_class": config["model"],
        }
    )
    print(f"Best CV ROC AUC: {best_trial.value:.4f}")
    print(f"Best params: {best_trial.params}\n")

# --- 5. Evaluate the Tuned Models on the Validation Set ---
print("\n--- Final Evaluation on Validation Set ---")
for model_info in best_models:
    # Instantiate and train the best model on the full training data
    FinalModel = model_info["model_class"]
    final_model = FinalModel(**model_info["best_params"], random_state=42)
    final_model.fit(X_train, y_train)

    # Evaluate on the hold-out validation set
    y_pred_proba = final_model.predict_proba(X_val)[:, 1]
    val_score = roc_auc_score(y_val, y_pred_proba)

    print(f"{model_info['name']}:")
    print(f"  Validation ROC AUC: {val_score:.4f}")
# Out:
# --- Tuning XGBoost ---
# [I 2025-08-19 19:47:42,762] A new study created in RDB with name: study-XGBoost
# Resuming study 'study-XGBoost'. 50 trials left to run.
# [I 2025-08-19 19:49:46,034] Trial 0 finished with value: 0.9631957528365922 and parameters: {'n_estimators': 500, 'learning_rate': 0.2536999076681771, 'max_depth': 8, 'subsample': 0.7993292420985183, 'colsample_bytree': 0.5780093202212182, 'gamma': 0.7799726016810132}. Best is trial 0 with value: 0.9631957528365922.
# [I 2025-08-19 19:50:31,872] Trial 1 finished with value: 0.9660641963106237 and parameters: {'n_estimators': 246, 'learning_rate': 0.19030368381735815, 'max_depth': 7, 'subsample': 0.8540362888980227, 'colsample_bytree': 0.5102922471479012, 'gamma': 4.8495492608099715}. Best is trial 1 with value: 0.9660641963106237.
# [I 2025-08-19 19:53:02,674] Trial 2 finished with value: 0.9639123355508641 and parameters: {'n_estimators': 866, 'learning_rate': 0.020589728197687916, 'max_depth': 4, 'subsample': 0.5917022549267169, 'colsample_bytree': 0.6521211214797689, 'gamma': 2.6237821581611893}. Best is trial 1 with value: 0.9660641963106237.
# [I 2025-08-19 19:55:16,727] Trial 3 finished with value: 0.9661628586582383 and parameters: {'n_estimators': 545, 'learning_rate': 0.02692655251486473, 'max_depth': 7, 'subsample': 0.569746930326021, 'colsample_bytree': 0.6460723242676091, 'gamma': 1.8318092164684585}. Best is trial 3 with value: 0.9661628586582383.
# [I 2025-08-19 19:56:44,998] Trial 4 finished with value: 0.9664850686783317 and parameters: {'n_estimators': 565, 'learning_rate': 0.14447746112718687, 'max_depth': 4, 'subsample': 0.7571172192068059, 'colsample_bytree': 0.7962072844310213, 'gamma': 0.23225206359998862}. Best is trial 4 with value: 0.9664850686783317.
# [I 2025-08-19 19:58:33,687] Trial 5 finished with value: 0.9607190982539585 and parameters: {'n_estimators': 686, 'learning_rate': 0.0178601378893971, 'max_depth': 3, 'subsample': 0.9744427686266666, 'colsample_bytree': 0.9828160165372797, 'gamma': 4.041986740582305}. Best is trial 4 with value: 0.9664850686783317.
# [I 2025-08-19 20:00:36,390] Trial 6 finished with value: 0.9647400538132394 and parameters: {'n_estimators': 443, 'learning_rate': 0.013940346079873234, 'max_depth': 7, 'subsample': 0.7200762468698007, 'colsample_bytree': 0.5610191174223894, 'gamma': 2.475884550556351}. Best is trial 4 with value: 0.9664850686783317.
# [I 2025-08-19 20:01:18,845] Trial 7 finished with value: 0.9656869146015771 and parameters: {'n_estimators': 227, 'learning_rate': 0.2203821893928988, 'max_depth': 4, 'subsample': 0.831261142176991, 'colsample_bytree': 0.6558555380447055, 'gamma': 2.600340105889054}. Best is trial 4 with value: 0.9664850686783317.
# [I 2025-08-19 20:04:26,547] Trial 8 finished with value: 0.9666816767614254 and parameters: {'n_estimators': 637, 'learning_rate': 0.01875220945578641, 'max_depth': 9, 'subsample': 0.8875664116805573, 'colsample_bytree': 0.9697494707820946, 'gamma': 4.474136752138244}. Best is trial 8 with value: 0.9666816767614254.
# [I 2025-08-19 20:06:00,799] Trial 9 finished with value: 0.9659067714499582 and parameters: {'n_estimators': 678, 'learning_rate': 0.22999586428143734, 'max_depth': 3, 'subsample': 0.5979914312095727, 'colsample_bytree': 0.522613644455269, 'gamma': 1.6266516538163218}. Best is trial 8 with value: 0.9666816767614254.
# [I 2025-08-19 20:08:25,114] Trial 10 finished with value: 0.9665441450370788 and parameters: {'n_estimators': 957, 'learning_rate': 0.0500220915772748, 'max_depth': 9, 'subsample': 0.9722495727394489, 'colsample_bytree': 0.9919371080730973, 'gamma': 3.9392129782685332}. Best is trial 8 with value: 0.9666816767614254.
# [I 2025-08-19 20:10:43,943] Trial 11 finished with value: 0.9662846318288354 and parameters: {'n_estimators': 984, 'learning_rate': 0.05434853880078047, 'max_depth': 9, 'subsample': 0.9986735852799455, 'colsample_bytree': 0.9979009436789888, 'gamma': 3.87859185644367}. Best is trial 8 with value: 0.9666816767614254.
# [I 2025-08-19 20:12:59,997] Trial 12 finished with value: 0.9667037934347118 and parameters: {'n_estimators': 818, 'learning_rate': 0.043812383564303524, 'max_depth': 9, 'subsample': 0.911550838365837, 'colsample_bytree': 0.9124260839977065, 'gamma': 4.988693868024801}. Best is trial 12 with value: 0.9667037934347118.
# [I 2025-08-19 20:15:29,818] Trial 13 finished with value: 0.9668280791186744 and parameters: {'n_estimators': 800, 'learning_rate': 0.037370046395123875, 'max_depth': 9, 'subsample': 0.8954178991106393, 'colsample_bytree': 0.884068608127012, 'gamma': 4.789774190969481}. Best is trial 13 with value: 0.9668280791186744.
# [I 2025-08-19 20:17:15,754] Trial 14 finished with value: 0.9664087379980335 and parameters: {'n_estimators': 795, 'learning_rate': 0.10247570188221387, 'max_depth': 8, 'subsample': 0.9282303174489941, 'colsample_bytree': 0.8721018272777807, 'gamma': 4.9789041447413265}. Best is trial 13 with value: 0.9668280791186744.
# [I 2025-08-19 20:19:53,327] Trial 15 finished with value: 0.9667251747124986 and parameters: {'n_estimators': 791, 'learning_rate': 0.03846242487211404, 'max_depth': 6, 'subsample': 0.6765827643791059, 'colsample_bytree': 0.8790784883264692, 'gamma': 3.427523040644671}. Best is trial 13 with value: 0.9668280791186744.
# [I 2025-08-19 20:22:24,628] Trial 16 finished with value: 0.9664284516153016 and parameters: {'n_estimators': 750, 'learning_rate': 0.03124421863909101, 'max_depth': 6, 'subsample': 0.6803710106053958, 'colsample_bytree': 0.8155421717694825, 'gamma': 3.256139655211496}. Best is trial 13 with value: 0.9668280791186744.
# [I 2025-08-19 20:24:58,768] Trial 17 finished with value: 0.9670183049600173 and parameters: {'n_estimators': 893, 'learning_rate': 0.0850956724116098, 'max_depth': 6, 'subsample': 0.6924745509172271, 'colsample_bytree': 0.8820246787153543, 'gamma': 3.2745361410518727}. Best is trial 17 with value: 0.9670183049600173.
# [I 2025-08-19 20:27:25,650] Trial 18 finished with value: 0.9669206071075231 and parameters: {'n_estimators': 885, 'learning_rate': 0.08830587574621247, 'max_depth': 5, 'subsample': 0.6367740053962987, 'colsample_bytree': 0.7255328935647928, 'gamma': 3.211810280697476}. Best is trial 17 with value: 0.9670183049600173.
# [I 2025-08-19 20:30:00,959] Trial 19 finished with value: 0.9665406274624232 and parameters: {'n_estimators': 921, 'learning_rate': 0.0845474845455667, 'max_depth': 5, 'subsample': 0.5037875075533402, 'colsample_bytree': 0.7285788471146385, 'gamma': 3.142975210088832}. Best is trial 17 with value: 0.9670183049600173.
# [I 2025-08-19 20:32:34,255] Trial 20 finished with value: 0.9669555442864362 and parameters: {'n_estimators': 894, 'learning_rate': 0.07895302325334252, 'max_depth': 5, 'subsample': 0.6534122320047089, 'colsample_bytree': 0.7184976690392566, 'gamma': 1.623382264106053}. Best is trial 17 with value: 0.9670183049600173.
# [I 2025-08-19 20:35:07,885] Trial 21 finished with value: 0.9669333376800291 and parameters: {'n_estimators': 896, 'learning_rate': 0.08281828765254538, 'max_depth': 5, 'subsample': 0.6435414858000282, 'colsample_bytree': 0.7408798806373582, 'gamma': 1.7545141915900044}. Best is trial 17 with value: 0.9670183049600173.
# [I 2025-08-19 20:37:57,612] Trial 22 finished with value: 0.9670685287799081 and parameters: {'n_estimators': 999, 'learning_rate': 0.07312641846626121, 'max_depth': 5, 'subsample': 0.7346731338817981, 'colsample_bytree': 0.7867388175087262, 'gamma': 1.493871115417365}. Best is trial 22 with value: 0.9670685287799081.
# [I 2025-08-19 20:40:39,648] Trial 23 finished with value: 0.9669662112557191 and parameters: {'n_estimators': 993, 'learning_rate': 0.13227980639943615, 'max_depth': 5, 'subsample': 0.7662322402404658, 'colsample_bytree': 0.7975822326669079, 'gamma': 1.194206278891895}. Best is trial 22 with value: 0.9670685287799081.
# [I 2025-08-19 20:43:46,104] Trial 24 finished with value: 0.9662118115379286 and parameters: {'n_estimators': 996, 'learning_rate': 0.1397624516047851, 'max_depth': 6, 'subsample': 0.7601806312903859, 'colsample_bytree': 0.8158810862857796, 'gamma': 1.190827544149556}. Best is trial 22 with value: 0.9670685287799081.
# [I 2025-08-19 20:46:29,465] Trial 25 finished with value: 0.9667850172726059 and parameters: {'n_estimators': 952, 'learning_rate': 0.13034043370996995, 'max_depth': 5, 'subsample': 0.7166401591849767, 'colsample_bytree': 0.7746989039417133, 'gamma': 0.8269752814114202}. Best is trial 22 with value: 0.9670685287799081.
# [I 2025-08-19 20:47:29,606] Trial 26 finished with value: 0.9641272085132719 and parameters: {'n_estimators': 311, 'learning_rate': 0.06522598793954372, 'max_depth': 4, 'subsample': 0.8149271154876796, 'colsample_bytree': 0.8423057456218509, 'gamma': 2.070802541990575}. Best is trial 22 with value: 0.9670685287799081.
# [I 2025-08-19 20:50:36,408] Trial 27 finished with value: 0.9665396818497646 and parameters: {'n_estimators': 992, 'learning_rate': 0.11546949133982272, 'max_depth': 6, 'subsample': 0.7237918314236818, 'colsample_bytree': 0.925348742330705, 'gamma': 0.09006108831077797}. Best is trial 22 with value: 0.9670685287799081.
# [I 2025-08-19 20:53:07,685] Trial 28 finished with value: 0.9650284439955202 and parameters: {'n_estimators': 727, 'learning_rate': 0.172108799624731, 'max_depth': 7, 'subsample': 0.7749639034710843, 'colsample_bytree': 0.7667420933436598, 'gamma': 1.1428969275416971}. Best is trial 22 with value: 0.9670685287799081.
# [I 2025-08-19 20:54:26,585] Trial 29 finished with value: 0.9656841915893031 and parameters: {'n_estimators': 453, 'learning_rate': 0.2974293928652366, 'max_depth': 5, 'subsample': 0.7887957332693476, 'colsample_bytree': 0.6916439289198394, 'gamma': 1.2018893055231568}. Best is trial 22 with value: 0.9670685287799081.
# [I 2025-08-19 20:57:05,602] Trial 30 finished with value: 0.9671335419174385 and parameters: {'n_estimators': 845, 'learning_rate': 0.06428138969028009, 'max_depth': 6, 'subsample': 0.695483477601958, 'colsample_bytree': 0.8268048195637326, 'gamma': 0.5365790663871404}. Best is trial 30 with value: 0.9671335419174385.
# [I 2025-08-19 20:59:45,398] Trial 31 finished with value: 0.967117293939942 and parameters: {'n_estimators': 841, 'learning_rate': 0.06125598578434948, 'max_depth': 6, 'subsample': 0.6972248821194833, 'colsample_bytree': 0.8436446235576004, 'gamma': 0.644090028610165}. Best is trial 30 with value: 0.9671335419174385.
# [I 2025-08-19 21:02:29,357] Trial 32 finished with value: 0.967102979779314 and parameters: {'n_estimators': 848, 'learning_rate': 0.06526221686640227, 'max_depth': 6, 'subsample': 0.6999029842195565, 'colsample_bytree': 0.8451222040988928, 'gamma': 0.5116287606711886}. Best is trial 30 with value: 0.9671335419174385.
# [I 2025-08-19 21:05:49,257] Trial 33 finished with value: 0.9669022941435094 and parameters: {'n_estimators': 840, 'learning_rate': 0.06147127051037581, 'max_depth': 8, 'subsample': 0.7280533613037625, 'colsample_bytree': 0.8452836014294214, 'gamma': 0.43077663412135975}. Best is trial 30 with value: 0.9671335419174385.
# [I 2025-08-19 21:08:19,297] Trial 34 finished with value: 0.9669028445128169 and parameters: {'n_estimators': 757, 'learning_rate': 0.06247173243441104, 'max_depth': 6, 'subsample': 0.6245039507209895, 'colsample_bytree': 0.926716288812301, 'gamma': 0.6102662358205395}. Best is trial 30 with value: 0.9671335419174385.
# [I 2025-08-19 21:11:26,755] Trial 35 finished with value: 0.9664757794744828 and parameters: {'n_estimators': 858, 'learning_rate': 0.06939748420455047, 'max_depth': 7, 'subsample': 0.5445249512950399, 'colsample_bytree': 0.8417340034725125, 'gamma': 0.8069271178131451}. Best is trial 30 with value: 0.9671335419174385.
# [I 2025-08-19 21:14:00,308] Trial 36 finished with value: 0.9660917901027103 and parameters: {'n_estimators': 711, 'learning_rate': 0.02668490737834893, 'max_depth': 6, 'subsample': 0.6959781158588285, 'colsample_bytree': 0.7659558598212435, 'gamma': 0.4193942280934989}. Best is trial 30 with value: 0.9671335419174385.
# [I 2025-08-19 21:16:21,347] Trial 37 finished with value: 0.9668453019523797 and parameters: {'n_estimators': 615, 'learning_rate': 0.04669595361713685, 'max_depth': 7, 'subsample': 0.6046753183337065, 'colsample_bytree': 0.9488883270200962, 'gamma': 0.06670311679180208}. Best is trial 30 with value: 0.9671335419174385.
# [I 2025-08-19 21:19:37,387] Trial 38 finished with value: 0.966373425979622 and parameters: {'n_estimators': 930, 'learning_rate': 0.10356046450026946, 'max_depth': 7, 'subsample': 0.7439928562789598, 'colsample_bytree': 0.8045944813292325, 'gamma': 0.9382411840194047}. Best is trial 30 with value: 0.9671335419174385.
# [I 2025-08-19 21:21:14,558] Trial 39 finished with value: 0.963902702236093 and parameters: {'n_estimators': 570, 'learning_rate': 0.032401012607699856, 'max_depth': 4, 'subsample': 0.8459499660738685, 'colsample_bytree': 0.6986396182085532, 'gamma': 0.5186386327271488}. Best is trial 30 with value: 0.9671335419174385.
# [I 2025-08-19 21:23:59,957] Trial 40 finished with value: 0.9670808754573553 and parameters: {'n_estimators': 848, 'learning_rate': 0.055910174668156794, 'max_depth': 6, 'subsample': 0.664691474638085, 'colsample_bytree': 0.8442508401830645, 'gamma': 1.448316506199873}. Best is trial 30 with value: 0.9671335419174385.
# [I 2025-08-19 21:26:41,971] Trial 41 finished with value: 0.9670432365211707 and parameters: {'n_estimators': 838, 'learning_rate': 0.05446036774799941, 'max_depth': 6, 'subsample': 0.6653735230135784, 'colsample_bytree': 0.851085444781476, 'gamma': 2.123348083709934}. Best is trial 30 with value: 0.9671335419174385.
# [I 2025-08-19 21:29:08,957] Trial 42 finished with value: 0.9670417985612719 and parameters: {'n_estimators': 754, 'learning_rate': 0.06957354071960695, 'max_depth': 6, 'subsample': 0.7037034882655249, 'colsample_bytree': 0.8271527377197412, 'gamma': 1.4630130463743964}. Best is trial 30 with value: 0.9671335419174385.
# [I 2025-08-19 21:32:21,953] Trial 43 finished with value: 0.9672866612262236 and parameters: {'n_estimators': 928, 'learning_rate': 0.043587132140967134, 'max_depth': 7, 'subsample': 0.7381642880984616, 'colsample_bytree': 0.7845159696285168, 'gamma': 1.435507759148219}. Best is trial 43 with value: 0.9672866612262236.
# [I 2025-08-19 21:35:17,655] Trial 44 finished with value: 0.9647450968187276 and parameters: {'n_estimators': 666, 'learning_rate': 0.01018739106267007, 'max_depth': 7, 'subsample': 0.6195350732512328, 'colsample_bytree': 0.8920674398176397, 'gamma': 0.2943572227609601}. Best is trial 43 with value: 0.9672866612262236.
# [I 2025-08-19 21:38:56,195] Trial 45 finished with value: 0.9668334694517785 and parameters: {'n_estimators': 933, 'learning_rate': 0.04195801009241162, 'max_depth': 8, 'subsample': 0.5705172873302569, 'colsample_bytree': 0.5993636108361037, 'gamma': 0.7478095974518865}. Best is trial 43 with value: 0.9672866612262236.
# [I 2025-08-19 21:41:54,126] Trial 46 finished with value: 0.9669842397897496 and parameters: {'n_estimators': 847, 'learning_rate': 0.05554674862575026, 'max_depth': 7, 'subsample': 0.6620966791699883, 'colsample_bytree': 0.8632893576780521, 'gamma': 2.018512187813285}. Best is trial 43 with value: 0.9672866612262236.
# [I 2025-08-19 21:44:50,473] Trial 47 finished with value: 0.9665796393753017 and parameters: {'n_estimators': 776, 'learning_rate': 0.022855327404756702, 'max_depth': 7, 'subsample': 0.7920020887474815, 'colsample_bytree': 0.900509797671606, 'gamma': 1.0122882081177895}. Best is trial 43 with value: 0.9672866612262236.
# [I 2025-08-19 21:47:28,754] Trial 48 finished with value: 0.9666545120597452 and parameters: {'n_estimators': 806, 'learning_rate': 0.03375544212319618, 'max_depth': 6, 'subsample': 0.7026293624342328, 'colsample_bytree': 0.8235989255626129, 'gamma': 1.3725856958428548}. Best is trial 43 with value: 0.9672866612262236.
# [I 2025-08-19 21:48:51,812] Trial 49 finished with value: 0.9664928904105421 and parameters: {'n_estimators': 296, 'learning_rate': 0.04838185011666178, 'max_depth': 8, 'subsample': 0.680646433867401, 'colsample_bytree': 0.7542652542840006, 'gamma': 2.4000003197941937}. Best is trial 43 with value: 0.9672866612262236.
# [I 2025-08-19 21:48:51,839] A new study created in RDB with name: study-KNeighbors
# Best CV ROC AUC: 0.9673
# Best params: {'n_estimators': 928, 'learning_rate': 0.043587132140967134, 'max_depth': 7, 'subsample': 0.7381642880984616, 'colsample_bytree': 0.7845159696285168, 'gamma': 1.435507759148219}
#
# --- Tuning KNeighbors ---
# Resuming study 'study-KNeighbors'. 50 trials left to run.
