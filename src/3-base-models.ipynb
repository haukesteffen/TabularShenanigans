# %%
import os
import pathlib

import joblib
import mlflow
import mlflow.sklearn
import mlflow.xgboost
import optuna
import pandas as pd
import sklearn
from sklearn.model_selection import (
    StratifiedKFold,
    cross_val_score,
    train_test_split,
)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sqlalchemy import create_engine
from xgboost import XGBClassifier

from utils.config import load_config
from utils.data import initialize_project

config_path = pathlib.Path.cwd().parent / "config.yaml"
config = load_config(config_path)
sklearn.set_config(transform_output="pandas")
joblib.parallel_backend("threading")
mlflow.set_tracking_uri("file:./mlruns")
mlflow.set_experiment("base-models")
print("Tracking URI:", mlflow.get_tracking_uri(), "CWD:", os.getcwd())

db_uri = initialize_project(config=config, init_db=False)
engine = create_engine(db_uri)
# Out:
# 2025/08/26 22:33:20 INFO mlflow.tracking.fluent: Experiment with name 'base-models' does not exist. Creating a new experiment.
# Config loaded from /Users/haukesteffen/dev/TabularShenanigans/config.yaml
# Tracking URI: file:./mlruns CWD: /Users/haukesteffen/dev/TabularShenanigans/src

# %%
with engine.begin() as connection:
    train = (
        pd.read_sql(
            sql=f"SELECT * FROM [{config.competition_name}-train-preprocessed]",
            con=connection,
        )
        .convert_dtypes()
        .sample(frac=1.0)
    )
    test = (
        pd.read_sql(
            sql=f"SELECT * FROM [{config.competition_name}-test-preprocessed]",
            con=connection,
        )
        .convert_dtypes()
        .sample(frac=1.0)
    )

train = train.set_index(config.id_column)

# subsample for faster experiments
train = train.sample(n=200_000)

X_train = train.drop(columns=[config.target_column])
y_train = train[config.target_column]

test = test.set_index(config.id_column)
X_test = test

X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.5, random_state=42
)

# %%
import warnings

warnings.filterwarnings(
    "ignore",
    message="Choices for a categorical distribution should be a tuple of None, bool, int, float and str",
    category=UserWarning,
)

# ------------------
# Config
# ------------------
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)


# ------------------
# Helper functions
# ------------------
def evaluate_with_logging(model_name, params, trial, model):
    score = cross_val_score(
        model, X_train, y_train, cv=cv, scoring="roc_auc", n_jobs=-1
    ).mean()

    # log this trial
    with mlflow.start_run(nested=True):
        mlflow.log_params(params)
        mlflow.log_metric("cv_score", score)
        mlflow.set_tag("trial_number", trial.number)
        mlflow.set_tag("model", model_name)

    return score


def make_estimator_and_logger(model_name: str, params: dict):
    """
    Returns (estimator, log_fn).
    log_fn(model, name, input_example) logs with the right MLflow flavor.
    """
    if model_name == "XGBoost":
        from xgboost import XGBClassifier

        est = XGBClassifier(**{**params, "n_jobs": -1, "random_state": 42})

        def log_fn(model, name, input_example=None):
            mlflow.xgboost.log_model(model, name=name, input_example=input_example)

        return est, log_fn

    elif model_name == "MLPClassifier":
        from sklearn.neural_network import MLPClassifier

        est = MLPClassifier(**{**params, "random_state": 42})

        def log_fn(model, name, input_example=None):
            mlflow.sklearn.log_model(model, name=name, input_example=input_example)

        return est, log_fn

    elif model_name == "KNeighborsClassifier":
        from sklearn.neighbors import KNeighborsClassifier

        est = KNeighborsClassifier(**params)

        def log_fn(model, name, input_example=None):
            mlflow.sklearn.log_model(model, name=name, input_example=input_example)

        return est, log_fn

    else:
        raise ValueError(f"Unknown model_name: {model_name}")


# ------------------
# Define search spaces
# ------------------
def xgb_objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 50, 250),
        "max_depth": trial.suggest_int("max_depth", 2, 8),
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.3, log=True),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "eval_metric": "logloss",
        "random_state": 42,
        "n_jobs": -1,
    }
    model = XGBClassifier(**params)
    return evaluate_with_logging("XGBoost", params, trial, model)


def mlp_objective(trial):
    hidden_layer_sizes = trial.suggest_categorical(
        "hidden_layer_sizes",
        [
            (50,),
            (100,),
            (150,),
            (200,),
            (50, 50),
            (100, 100),
            (150, 150),
            (200, 100),
            (100, 50),
            (200, 50),
        ],
    )
    params = {
        "hidden_layer_sizes": hidden_layer_sizes,
        "alpha": trial.suggest_float("alpha", 1e-5, 1e-1, log=True),
        "learning_rate_init": trial.suggest_float(
            "learning_rate_init", 1e-4, 1e-1, log=True
        ),
        "max_iter": 500,
        "random_state": 42,
    }
    model = MLPClassifier(**params)
    return evaluate_with_logging("MLPClassifier", params, trial, model)


def knn_objective(trial):
    params = {
        "n_neighbors": trial.suggest_int("n_neighbors", 2, 24),
        "weights": trial.suggest_categorical("weights", ["uniform", "distance"]),
        "p": trial.suggest_int("p", 1, 2),
    }
    model = KNeighborsClassifier(**params)
    return evaluate_with_logging("KNeighborsClassifier", params, trial, model)


# ------------------
# Run studies + MLflow logging
# ------------------
def run_study(model_name, objective, n_trials=30):
    with mlflow.start_run(run_name=f"{model_name}_tuning") as parent_run:
        mlflow.set_tag("phase", "tuning_started")
        mlflow.log_param("n_trials", n_trials)

        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=n_trials)

        # best params/score
        best_params = study.best_trial.params
        mlflow.log_params({f"best_{k}": v for k, v in best_params.items()})
        mlflow.log_metric("best_cv_score", study.best_value)

        # fit full data + log with correct flavor
        est, log_fn = make_estimator_and_logger(model_name, best_params)
        est.fit(X_train, y_train)
        log_fn(est, name=f"{model_name}_best_model", input_example=X_train[:5])

        # (optional) persist study
        # os.makedirs("studies", exist_ok=True)
        # joblib.dump(study, f"studies/{model_name}_study.pkl")

    return best_params, study.best_value


# ------------------
# Run all models
# ------------------
best_mlp, mlp_score = run_study("MLPClassifier", mlp_objective, n_trials=50)
best_xgb, xgb_score = run_study("XGBoost", xgb_objective, n_trials=50)
best_knn, knn_score = run_study("KNeighborsClassifier", knn_objective, n_trials=50)

print(f"Best XGB: {best_xgb} with score {xgb_score:.4f}")
print(f"Best MLP: {best_mlp} with score {mlp_score:.4f}")
print(f"Best KNN: {best_knn} with score {knn_score:.4f}")
# Out:
# [I 2025-08-26 22:33:24,967] A new study created in memory with name: no-name-99bafc94-e97a-4d0d-bc59-03ed8e99dec8
# /Users/haukesteffen/dev/TabularShenanigans/.venv/lib/python3.13/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/haukesteffen/dev/TabularShenanigans/.venv/lib/python3.13/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/haukesteffen/dev/TabularShenanigans/.venv/lib/python3.13/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/haukesteffen/dev/TabularShenanigans/.venv/lib/python3.13/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-08-26 22:42:55,348] Trial 0 finished with value: 0.9293730781868526 and parameters: {'hidden_layer_sizes': (100, 100), 'alpha': 0.0006628544610972243, 'learning_rate_init': 0.00012870445586976405}. Best is trial 0 with value: 0.9293730781868526.
# /Users/haukesteffen/dev/TabularShenanigans/.venv/lib/python3.13/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/
# [I 2025-08-26 23:24:33,965] Trial 13 finished with value: 0.9553236651963533 and parameters: {'hidden_layer_sizes': (50, 50), 'alpha': 0.09833105864748189, 'learning_rate_init': 0.0007036922931054668}. Best is trial 13 with value: 0.9553236651963533.
# [I 2025-08-26 23:26:53,739] Trial 14 finished with value: 0.9469770655771754 and parameters: {'hidden_layer_sizes': (100,), 'alpha': 0.010199498136833903, 'learning_rate_init': 0.0007671352984066533}. Best is trial 13 with value: 0.9553236651963533.
# [I 2025-08-26 23:27:35,952] Trial 15 finished with value: 0.9529933962626954 and parameters: {'hidden_layer_sizes': (200,), 'alpha': 0.010124246999721575, 'learning_rate_init': 0.008810836130563318}. Best is trial 13 with value: 0.9553236651963533.
# [I 2025-08-26 23:29:14,118] Trial 16 finished with value: 0.9565034968391048 and parameters: {'hidden_layer_sizes': (200, 50), 'alpha': 0.09969251532846181, 'learning_rate_init': 0.0008457813081103524}. Best is trial 16 with value: 0.9565034968391048.
# [I 2025-08-26 23:32:25,173] Trial 17 finished with value: 0.9310957752067293 and parameters: {'hidden_layer_sizes': (150, 150), 'alpha': 1.6433133071924397e-05, 'learning_rate_init': 0.0009404867156213077}. Best is trial 16 with value: 0.9565034968391048.
# [I 2025-08-26 23:33:50,270] Trial 18 finished with value: 0.955663056045546 and parameters: {'hidden_layer_sizes': (200, 50), 'alpha': 0.004725306540713499, 'learning_rate_init': 0.007460337223140086}. Best is trial 16 with value: 0.9565034968391048.
# [I 2025-08-26 23:34:49,567] Trial 19 finished with value: 0.9534005314242643 and parameters: {'hidden_layer_sizes': (200, 50), 'alpha': 0.00427429281887549, 'learning_rate_init': 0.016108102755954732}. Best is trial 16 with value: 0.9565034968391048.
# [I 2025-08-26 23:38:02,334] Trial 20 finished with value: 0.9406635094505568 and parameters: {'hidden_layer_sizes': (200, 50), 'alpha': 9.835658969845947e-05, 'learning_rate_init': 0.00718946037403968}. Best is trial 16 with value: 0.9565034968391048.
# [I 2025-08-26 23:42:04,831] Trial 21 finished with value: 0.9382651695634017 and parameters: {'hidden_layer_sizes': (200, 50), 'alpha': 0.017202854026059398, 'learning_rate_init': 0.001111859635343651}. Best is trial 16 with value: 0.9565034968391048.
# [I 2025-08-26 23:42:56,457] Trial 22 finished with value: 0.9471074229798194 and parameters: {'hidden_layer_sizes': (200, 50), 'alpha': 0.025727198202826672, 'learning_rate_init': 0.018085531689757045}. Best is trial 16 with value: 0.9565034968391048.
# [I 2025-08-26 23:43:51,183] Trial 23 finished with value: 0.9515519253909256 and parameters: {'hidden_layer_sizes': (200, 50), 'alpha': 0.08539404981468238, 'learning_rate_init': 0.005386568801444692}. Best is trial 16 with value: 0.9565034968391048.
# [I 2025-08-26 23:49:22,155] Trial 24 finished with value: 0.9279617991796482 and parameters: {'hidden_layer_sizes': (100, 50), 'alpha': 0.0031387326798963332, 'learning_rate_init': 0.0005894621672640698}. Best is trial 16 with value: 0.9565034968391048.
# [I 2025-08-26 23:51:56,103] Trial 25 finished with value: 0.9418798575889665 and parameters: {'hidden_layer_sizes': (200,), 'alpha': 0.0036533981802838508, 'learning_rate_init': 0.0015106601422232209}. Best is trial 16 with value: 0.9565034968391048.
# [I 2025-08-26 23:52:56,774] Trial 26 finished with value: 0.9520107998394515 and parameters: {'hidden_layer_sizes': (150, 150), 'alpha': 0.020958009084612372, 'learning_rate_init': 0.012821118578253925}. Best is trial 16 with value: 0.9565034968391048.
# [I 2025-08-26 23:53:24,285] Trial 27 finished with value: 0.9503171413902363 and parameters: {'hidden_layer_sizes': (100,), 'alpha': 0.00013091812114190285, 'learning_rate_init': 0.030380448747299584}. Best is trial 16 with value: 0.9565034968391048.
# [I 2025-08-26 23:56:06,980] Trial 28 finished with value: 0.956162124483396 and parameters: {'hidden_layer_sizes': (50,), 'alpha': 0.04017532378888522, 'learning_rate_init': 0.00011664792849635671}. Best is trial 16 with value: 0.9565034968391048.
# [I 2025-08-26 23:59:19,749] Trial 29 finished with value: 0.9526351125447826 and parameters: {'hidden_layer_sizes': (50,), 'alpha': 0.005763995309521192, 'learning_rate_init': 0.00021041354184180515}. Best is trial 16 with value: 0.9565034968391048.
# [I 2025-08-27 00:02:04,763] Trial 30 finished with value: 0.9557404172358449 and parameters: {'hidden_layer_sizes': (50,), 'alpha': 0.037703663897695, 'learning_rate_init': 0.00014659597041540416}. Best is trial 16 with value: 0.9565034968391048.
# [I 2025-08-27 00:05:11,300] Trial 31 finished with value: 0.9564230115448747 and parameters: {'hidden_layer_sizes': (50,), 'alpha': 0.039580796780833045, 'learning_rate_init': 0.0001023817625857518}. Best is trial 16 with value: 0.9565034968391048.
# [I 2025-08-27 00:08:05,817] Trial 32 finished with value: 0.9565888938499553 and parameters: {'hidden_layer_sizes': (50,), 'alpha': 0.04862035233709538, 'learning_rate_init': 0.00010744139009406221}. Best is trial 32 with value: 0.9565888938499553.
# [I 2025-08-27 00:10:52,002] Trial 33 finished with value: 0.9564810238619008 and parameters: {'hidden_layer_sizes': (50,), 'alpha': 0.04163207373266368, 'learning_rate_init': 0.00010355531365351502}. Best is trial 32 with value: 0.9565888938499553.
# [I 2025-08-27 00:14:21,299] Trial 34 finished with value: 0.9556468593785368 and parameters: {'hidden_layer_sizes': (50,), 'alpha': 0.015346910662556307, 'learning_rate_init': 0.00010097141699833043}. Best is trial 32 with value: 0.9565888938499553.
# [I 2025-08-27 00:19:16,929] Trial 35 finished with value: 0.9443256026220406 and parameters: {'hidden_layer_sizes': (100, 100), 'alpha': 0.05628823567923598, 'learning_rate_init': 0.0003142674821176393}. Best is trial 32 with value: 0.9565888938499553.
# [I 2025-08-27 00:22:05,661] Trial 36 finished with value: 0.9551147941012786 and parameters: {'hidden_layer_sizes': (50,), 'alpha': 0.026815484593533712, 'learning_rate_init': 0.0001625282911058973}. Best is trial 32 with value: 0.9565888938499553.
# [I 2025-08-27 00:25:54,519] Trial 37 finished with value: 0.950704702923914 and parameters: {'hidden_layer_sizes': (50,), 'alpha': 0.0017672584624028786, 'learning_rate_init': 0.00025623188591961}. Best is trial 32 with value: 0.9565888938499553.
# [I 2025-08-27 00:28:22,389] Trial 38 finished with value: 0.9558598375340572 and parameters: {'hidden_layer_sizes': (50,), 'alpha': 0.04513025419931331, 'learning_rate_init': 0.00015683087901525582}. Best is trial 32 with value: 0.9565888938499553.
# [I 2025-08-27 00:31:42,760] Trial 39 finished with value: 0.9501576371286484 and parameters: {'hidden_layer_sizes': (150,), 'alpha': 0.027209224400822796, 'learning_rate_init': 0.0003684976234531061}. Best is trial 32 with value: 0.9565888938499553.
# [I 2025-08-27 00:39:11,420] Trial 40 finished with value: 0.9433926048060096 and parameters: {'hidden_layer_sizes': (100, 100), 'alpha': 0.055318289183150425, 'learning_rate_init': 0.00010338598142055618}. Best is trial 32 with value: 0.9565888938499553.
# [I 2025-08-27 00:41:46,551] Trial 41 finished with value: 0.9557158955818983 and parameters: {'hidden_layer_sizes': (50,), 'alpha': 0.03616102351520482, 'learning_rate_init': 0.00012950889023803283}. Best is trial 32 with value: 0.9565888938499553.
# [I 2025-08-27 00:44:39,750] Trial 42 finished with value: 0.9537343589895663 and parameters: {'hidden_layer_sizes': (50,), 'alpha': 0.013937188657808212, 'learning_rate_init': 0.00021138861944221404}. Best is trial 32 with value: 0.9565888938499553.
# [I 2025-08-27 00:47:02,752] Trial 43 finished with value: 0.9566839766996453 and parameters: {'hidden_layer_sizes': (50,), 'alpha': 0.05585037847660343, 'learning_rate_init': 0.00010513356077035176}. Best is trial 43 with value: 0.9566839766996453.
# [I 2025-08-27 00:49:49,853] Trial 44 finished with value: 0.9561078763348826 and parameters: {'hidden_layer_sizes': (50,), 'alpha': 0.06088345568071799, 'learning_rate_init': 0.00017559559089094255}. Best is trial 43 with value: 0.9566839766996453.
# [I 2025-08-27 00:56:29,381] Trial 45 finished with value: 0.9331676825411132 and parameters: {'hidden_layer_sizes': (200, 100), 'alpha': 0.007123265526858852, 'learning_rate_init': 0.000263245910159203}. Best is trial 43 with value: 0.9566839766996453.
# [I 2025-08-27 00:57:44,443] Trial 46 finished with value: 0.9560050309488467 and parameters: {'hidden_layer_sizes': (50,), 'alpha': 0.09820348101300927, 'learning_rate_init': 0.0004934238677546234}. Best is trial 43 with value: 0.9566839766996453.
# /Users/haukesteffen/dev/TabularShenanigans/.venv/lib/python3.13/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/haukesteffen/dev/TabularShenanigans/.venv/lib/python3.13/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/haukesteffen/dev/TabularShenanigans/.venv/lib/python3.13/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/haukesteffen/dev/TabularShenanigans/.venv/lib/python3.13/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/haukesteffen/dev/TabularShenanigans/.venv/lib/python3.13/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-08-27 01:04:22,077] Trial 47 finished with value: 0.9469750749328874 and parameters: {'hidden_layer_sizes': (150,), 'alpha': 0.0002450022303781568, 'learning_rate_init': 0.00010108491183124301}. Best is trial 43 with value: 0.9566839766996453.
# [I 2025-08-27 01:05:48,770] Trial 48 finished with value: 0.9559552279562634 and parameters: {'hidden_layer_sizes': (50,), 'alpha': 0.06289289508489171, 'learning_rate_init': 0.00037114797390733504}. Best is trial 43 with value: 0.9566839766996453.
# [I 2025-08-27 01:06:28,167] Trial 49 finished with value: 0.8278435513035136 and parameters: {'hidden_layer_sizes': (100, 50), 'alpha': 0.028839695079825898, 'learning_rate_init': 0.08478466395911723}. Best is trial 43 with value: 0.9566839766996453.
# /Users/haukesteffen/dev/TabularShenanigans/.venv/lib/python3.13/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2025/08/27 01:07:08 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# [I 2025-08-27 01:07:08,709] A new study created in memory with name: no-name-7722c015-bbcc-4c8a-9ea9-f1fe2efad4a0
# [I 2025-08-27 01:07:20,896] Trial 0 finished with value: 0.9603998407690597 and parameters: {'n_estimators': 229, 'max_depth': 8, 'learning_rate': 0.013879307767680801, 'subsample': 0.6892641894481255, 'colsample_bytree': 0.7133795813913332}. Best is trial 0 with value: 0.9603998407690597.
# [I 2025-08-27 01:07:26,271] Trial 1 finished with value: 0.9597809607032488 and parameters: {'n_estimators': 101, 'max_depth': 7, 'learning_rate': 0.03583318538165731, 'subsample': 0.6645186810359474, 'colsample_bytree': 0.8755467022739083}. Best is trial 0 with value: 0.9603998407690597.
# [I 2025-08-27 01:07:31,602] Trial 2 finished with value: 0.960980717368461 and parameters: {'n_estimators': 130, 'max_depth': 6, 'learning_rate': 0.05140840107773251, 'subsample': 0.6037557958401256, 'colsample_bytree': 0.6416296193099263}. Best is trial 2 with value: 0.960980717368461.
# [I 2025-08-27 01:07:36,630] Trial 3 finished with value: 0.939302690907633 and parameters: {'n_estimators': 232, 'max_depth': 2, 'learning_rate': 0.012208202944205878, 'subsample': 0.8447141017676031, 'colsample_bytree': 0.8234077158963146}. Best is trial 2 with value: 0.960980717368461.
# [I 2025-08-27 01:07:43,426] Trial 4 finished with value: 0.9617351917175541 and parameters: {'n_estimators': 229, 'max_depth': 5, 'learning_rate': 0.07209577934066372, 'subsample': 0.860986688255628, 'colsample_bytree': 0.8711552099849538}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:07:52,417] Trial 5 finished with value: 0.9594653351844658 and parameters: {'n_estimators': 220, 'max_depth': 8, 'learning_rate': 0.16182645095176876, 'subsample': 0.9787747683032466, 'colsample_bytree': 0.6240796820108274}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:07:55,693] Trial 6 finished with value: 0.9537119397167334 and parameters: {'n_estimators': 50, 'max_depth': 7, 'learning_rate': 0.008755074713670267, 'subsample': 0.674911390438806, 'colsample_bytree': 0.7482895821245249}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:08:03,027] Trial 7 finished with value: 0.9468181732386837 and parameters: {'n_estimators': 238, 'max_depth': 5, 'learning_rate': 0.002126913729516181, 'subsample': 0.9030474347013016, 'colsample_bytree': 0.9708298437386422}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:08:09,958] Trial 8 finished with value: 0.9489365432316579 and parameters: {'n_estimators': 238, 'max_depth': 5, 'learning_rate': 0.0015644298144682739, 'subsample': 0.8698299690513713, 'colsample_bytree': 0.6662712329124316}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:08:14,223] Trial 9 finished with value: 0.9521672669561679 and parameters: {'n_estimators': 60, 'max_depth': 8, 'learning_rate': 0.0041020406643501855, 'subsample': 0.6785888075135957, 'colsample_bytree': 0.9947446013237347}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:08:18,667] Trial 10 finished with value: 0.9601930554184375 and parameters: {'n_estimators': 182, 'max_depth': 3, 'learning_rate': 0.24326535465381316, 'subsample': 0.5298294749338899, 'colsample_bytree': 0.5038977826817619}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:08:23,155] Trial 11 finished with value: 0.9598804274017125 and parameters: {'n_estimators': 143, 'max_depth': 4, 'learning_rate': 0.06102833869587462, 'subsample': 0.5163947622738565, 'colsample_bytree': 0.5701871268598346}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:08:29,140] Trial 12 finished with value: 0.9614195266421524 and parameters: {'n_estimators': 148, 'max_depth': 6, 'learning_rate': 0.0690784580532151, 'subsample': 0.8071112969378671, 'colsample_bytree': 0.8859531094777923}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:08:35,559] Trial 13 finished with value: 0.9615586661794696 and parameters: {'n_estimators': 176, 'max_depth': 6, 'learning_rate': 0.09130176544487402, 'subsample': 0.7922983482721362, 'colsample_bytree': 0.8654332234992453}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:08:40,582] Trial 14 finished with value: 0.9614229472146437 and parameters: {'n_estimators': 185, 'max_depth': 4, 'learning_rate': 0.12528617349608992, 'subsample': 0.7770711451124188, 'colsample_bytree': 0.8525123455924265}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:08:48,132] Trial 15 finished with value: 0.9606132215790499 and parameters: {'n_estimators': 191, 'max_depth': 6, 'learning_rate': 0.02786481900786149, 'subsample': 0.9451550184594937, 'colsample_bytree': 0.7892447052485796}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:08:53,480] Trial 16 finished with value: 0.9614734835561141 and parameters: {'n_estimators': 202, 'max_depth': 4, 'learning_rate': 0.10338525777325719, 'subsample': 0.755604981225124, 'colsample_bytree': 0.9302307459129343}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:08:58,662] Trial 17 finished with value: 0.9590279089209691 and parameters: {'n_estimators': 168, 'max_depth': 5, 'learning_rate': 0.2758490086604763, 'subsample': 0.828466040201742, 'colsample_bytree': 0.9083726192897374}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:09:04,699] Trial 18 finished with value: 0.9592080860912745 and parameters: {'n_estimators': 114, 'max_depth': 7, 'learning_rate': 0.02553576229264838, 'subsample': 0.8788558373203323, 'colsample_bytree': 0.8262157994448834}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:09:09,896] Trial 19 finished with value: 0.9437197833081583 and parameters: {'n_estimators': 207, 'max_depth': 3, 'learning_rate': 0.005727588424164933, 'subsample': 0.9321798296769346, 'colsample_bytree': 0.7721733791331422}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:10:22,961] Trial 31 finished with value: 0.9615652096594383 and parameters: {'n_estimators': 198, 'max_depth': 4, 'learning_rate': 0.10930396239104002, 'subsample': 0.7642036652115564, 'colsample_bytree': 0.8584319789614733}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:10:29,165] Trial 32 finished with value: 0.9600474262591927 and parameters: {'n_estimators': 181, 'max_depth': 5, 'learning_rate': 0.032277389286242485, 'subsample': 0.712510157240101, 'colsample_bytree': 0.8620739253258873}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:10:34,648] Trial 33 finished with value: 0.9606036022394294 and parameters: {'n_estimators': 197, 'max_depth': 4, 'learning_rate': 0.05730943171529592, 'subsample': 0.7704928574319313, 'colsample_bytree': 0.7682389299626576}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:10:39,592] Trial 34 finished with value: 0.9601500325990411 and parameters: {'n_estimators': 158, 'max_depth': 5, 'learning_rate': 0.2282682428886715, 'subsample': 0.8235898048875896, 'colsample_bytree': 0.889301718778815}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:10:45,114] Trial 35 finished with value: 0.9614187827657608 and parameters: {'n_estimators': 219, 'max_depth': 4, 'learning_rate': 0.15809363878212468, 'subsample': 0.8608650364330745, 'colsample_bytree': 0.8446403925501351}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:10:49,020] Trial 36 finished with value: 0.9609030017284125 and parameters: {'n_estimators': 82, 'max_depth': 6, 'learning_rate': 0.11405462644232404, 'subsample': 0.6551185071749871, 'colsample_bytree': 0.7295440057048675}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:10:52,944] Trial 37 finished with value: 0.9455428316902985 and parameters: {'n_estimators': 134, 'max_depth': 3, 'learning_rate': 0.01185067332875814, 'subsample': 0.9936981558896362, 'colsample_bytree': 0.8130417934926583}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:11:00,017] Trial 38 finished with value: 0.9614220023712161 and parameters: {'n_estimators': 233, 'max_depth': 5, 'learning_rate': 0.04496429444450516, 'subsample': 0.7417817674951825, 'colsample_bytree': 0.6805548458839639}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:11:03,985] Trial 39 finished with value: 0.956487608240199 and parameters: {'n_estimators': 182, 'max_depth': 2, 'learning_rate': 0.07058876861335772, 'subsample': 0.7860415703049464, 'colsample_bytree': 0.8959322963090037}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:11:11,479] Trial 40 finished with value: 0.955533219359187 and parameters: {'n_estimators': 212, 'max_depth': 6, 'learning_rate': 0.2987091508462547, 'subsample': 0.6977460931836256, 'colsample_bytree': 0.9737327465479622}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:11:16,866] Trial 41 finished with value: 0.9613192473244621 and parameters: {'n_estimators': 200, 'max_depth': 4, 'learning_rate': 0.09722864098469464, 'subsample': 0.7525967838299433, 'colsample_bytree': 0.9372323708762352}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:11:22,704] Trial 42 finished with value: 0.961256927139931 and parameters: {'n_estimators': 226, 'max_depth': 4, 'learning_rate': 0.12906918728456632, 'subsample': 0.6537749756161565, 'colsample_bytree': 0.8612036457716936}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:11:28,653] Trial 43 finished with value: 0.9604344558100102 and parameters: {'n_estimators': 202, 'max_depth': 5, 'learning_rate': 0.19640697040427607, 'subsample': 0.8236288895371453, 'colsample_bytree': 0.9669923339898888}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:11:33,540] Trial 44 finished with value: 0.9615509983662806 and parameters: {'n_estimators': 176, 'max_depth': 4, 'learning_rate': 0.10727246495034991, 'subsample': 0.8538050546079489, 'colsample_bytree': 0.9991426280384322}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:11:38,047] Trial 45 finished with value: 0.9587372013231498 and parameters: {'n_estimators': 175, 'max_depth': 3, 'learning_rate': 0.05744392111553361, 'subsample': 0.9256179793678447, 'colsample_bytree': 0.995541774564436}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:11:43,007] Trial 46 finished with value: 0.9615499648288207 and parameters: {'n_estimators': 190, 'max_depth': 4, 'learning_rate': 0.1435147253382646, 'subsample': 0.8521562460448301, 'colsample_bytree': 0.7566215402625389}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:11:47,766] Trial 47 finished with value: 0.9613724504348653 and parameters: {'n_estimators': 151, 'max_depth': 5, 'learning_rate': 0.14919552535561986, 'subsample': 0.8636714944871271, 'colsample_bytree': 0.5921276526755543}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:11:54,941] Trial 48 finished with value: 0.9580721983480702 and parameters: {'n_estimators': 189, 'max_depth': 7, 'learning_rate': 0.23309059862726575, 'subsample': 0.9098548624616007, 'colsample_bytree': 0.6830395360288871}. Best is trial 4 with value: 0.9617351917175541.
# [I 2025-08-27 01:12:02,642] Trial 49 finished with value: 0.961446838749261 and parameters: {'n_estimators': 156, 'max_depth': 8, 'learning_rate': 0.06799167250595309, 'subsample': 0.9664828022193982, 'colsample_bytree': 0.6342222900956516}. Best is trial 4 with value: 0.9617351917175541.
# /Users/haukesteffen/dev/TabularShenanigans/.venv/lib/python3.13/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# /Users/haukesteffen/dev/TabularShenanigans/.venv/lib/python3.13/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# /Users/haukesteffen/dev/TabularShenanigans/.venv/lib/python3.13/site-packages/xgboost/sklearn.py:1028: UserWarning: [01:12:05] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1427: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   self.get_booster().save_model(fname)
# 2025/08/27 01:12:07 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# [I 2025-08-27 01:12:07,346] A new study created in memory with name: no-name-fa9cb578-8de2-4a5a-8439-29846c93cd6e
# [I 2025-08-27 01:14:39,227] Trial 0 finished with value: 0.9296894804904141 and parameters: {'n_neighbors': 23, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.9296894804904141.
# [I 2025-08-27 01:17:10,855] Trial 1 finished with value: 0.9271897220991733 and parameters: {'n_neighbors': 17, 'weights': 'distance', 'p': 1}. Best is trial 0 with value: 0.9296894804904141.
# [I 2025-08-27 01:19:42,340] Trial 2 finished with value: 0.9192818325379287 and parameters: {'n_neighbors': 12, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.9296894804904141.
# [I 2025-08-27 01:19:51,110] Trial 3 finished with value: 0.926294081307051 and parameters: {'n_neighbors': 16, 'weights': 'distance', 'p': 2}. Best is trial 0 with value: 0.9296894804904141.
# [I 2025-08-27 01:22:22,755] Trial 4 finished with value: 0.9277426017640575 and parameters: {'n_neighbors': 20, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.9296894804904141.
# [I 2025-08-27 01:24:54,100] Trial 5 finished with value: 0.9147442645504602 and parameters: {'n_neighbors': 10, 'weights': 'uniform', 'p': 1}. Best is trial 0 with value: 0.9296894804904141.
# [I 2025-08-27 01:25:02,861] Trial 6 finished with value: 0.9212836947521759 and parameters: {'n_neighbors': 13, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.9296894804904141.
# [I 2025-08-27 01:25:11,980] Trial 7 finished with value: 0.9271458246900034 and parameters: {'n_neighbors': 19, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.9296894804904141.
# [I 2025-08-27 01:25:20,636] Trial 8 finished with value: 0.9180358126327619 and parameters: {'n_neighbors': 11, 'weights': 'uniform', 'p': 2}. Best is trial 0 with value: 0.9296894804904141.
# [I 2025-08-27 01:27:52,090] Trial 9 finished with value: 0.9281914168054402 and parameters: {'n_neighbors': 18, 'weights': 'distance', 'p': 1}. Best is trial 0 with value: 0.9296894804904141.
# [I 2025-08-27 01:30:24,057] Trial 10 finished with value: 0.9318538057378511 and parameters: {'n_neighbors': 24, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 0.9318538057378511.
# [I 2025-08-27 01:32:55,721] Trial 11 finished with value: 0.9312753511932061 and parameters: {'n_neighbors': 23, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 0.9318538057378511.
# [I 2025-08-27 01:35:27,143] Trial 12 finished with value: 0.850592752054653 and parameters: {'n_neighbors': 3, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 0.9318538057378511.
# [I 2025-08-27 01:37:58,971] Trial 13 finished with value: 0.9318538057378511 and parameters: {'n_neighbors': 24, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 0.
'weights': 'distance', 'p': 1}. Best is trial 10 with value: 0.9318538057378511.
# [I 2025-08-27 02:34:03,320] Trial 38 finished with value: 0.9257385262351197 and parameters: {'n_neighbors': 17, 'weights': 'uniform', 'p': 2}. Best is trial 10 with value: 0.9318538057378511.
# [I 2025-08-27 02:36:34,927] Trial 39 finished with value: 0.9277426017640575 and parameters: {'n_neighbors': 20, 'weights': 'uniform', 'p': 1}. Best is trial 10 with value: 0.9318538057378511.
# [I 2025-08-27 02:39:06,383] Trial 40 finished with value: 0.9318538057378511 and parameters: {'n_neighbors': 24, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 0.9318538057378511.
# [I 2025-08-27 02:41:38,220] Trial 41 finished with value: 0.9318538057378511 and parameters: {'n_neighbors': 24, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 0.9318538057378511.
# [I 2025-08-27 02:44:09,836] Trial 42 finished with value: 0.9312753511932061 and parameters: {'n_neighbors': 23, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 0.9318538057378511.
# [I 2025-08-27 02:46:41,582] Trial 43 finished with value: 0.9300438963515777 and parameters: {'n_neighbors': 21, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 0.9318538057378511.
# [I 2025-08-27 02:49:13,142] Trial 44 finished with value: 0.9312753511932061 and parameters: {'n_neighbors': 23, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 0.9318538057378511.
# [I 2025-08-27 02:51:44,693] Trial 45 finished with value: 0.9293812187114876 and parameters: {'n_neighbors': 20, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 0.9318538057378511.
# [I 2025-08-27 02:54:16,357] Trial 46 finished with value: 0.9290069961532625 and parameters: {'n_neighbors': 22, 'weights': 'uniform', 'p': 1}. Best is trial 10 with value: 0.9318538057378511.
# [I 2025-08-27 02:54:25,487] Trial 47 finished with value: 0.9279302545089358 and parameters: {'n_neighbors': 18, 'weights': 'distance', 'p': 2}. Best is trial 10 with value: 0.9318538057378511.
# [I 2025-08-27 02:56:56,893] Trial 48 finished with value: 0.913121956100478 and parameters: {'n_neighbors': 9, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 0.9318538057378511.
# [I 2025-08-27 02:59:28,412] Trial 49 finished with value: 0.9318538057378511 and parameters: {'n_neighbors': 24, 'weights': 'distance', 'p': 1}. Best is trial 10 with value: 0.9318538057378511.
# /Users/haukesteffen/dev/TabularShenanigans/.venv/lib/python3.13/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2025/08/27 02:59:30 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Best XGB: {'n_estimators': 229, 'max_depth': 5, 'learning_rate': 0.07209577934066372, 'subsample': 0.860986688255628, 'colsample_bytree': 0.8711552099849538} with score 0.9617
# Best MLP: {'hidden_layer_sizes': (50,), 'alpha': 0.05585037847660343, 'learning_rate_init': 0.00010513356077035176} with score 0.9567
# Best KNN: {'n_neighbors': 24, 'weights': 'distance', 'p': 1} with score 0.9319
