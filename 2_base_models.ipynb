# %%
import json

import pandas as pd
from scipy.stats import loguniform, randint, uniform
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.experimental import enable_halving_search_cv  # noqa
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import HalvingRandomSearchCV, StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier

from utils.config import load_config

config = load_config("config.yaml")
# Out:
# Config loaded from config.yaml.

# %%
X_train = pd.read_csv(
    config.data_path / config.X_train_file, index_col="id"
).convert_dtypes()
y_train = pd.read_csv(
    config.data_path / config.y_train_file, index_col="id"
).convert_dtypes()
X_val = pd.read_csv(
    config.data_path / config.X_val_file, index_col="id"
).convert_dtypes()
y_val = pd.read_csv(
    config.data_path / config.y_val_file, index_col="id"
).convert_dtypes()
X_test = pd.read_csv(
    config.data_path / config.X_test_file, index_col="id"
).convert_dtypes()

# %%
models_and_params = {
    # ===== LOGISTIC REGRESSION =====
    "logreg": (
        LogisticRegression(max_iter=5000, random_state=42),
        [
            {
                "penalty": ["l2"],
                "C": loguniform(1e-2, 1e4),
                "solver": ["lbfgs", "newton-cg", "sag", "saga"],
            },
            {
                "penalty": ["l1"],
                "C": loguniform(1e-2, 1e4),
                "solver": ["liblinear", "saga"],
            },
            {
                "penalty": ["elasticnet"],
                "C": loguniform(1e-2, 1e4),
                "solver": ["saga"],
                "l1_ratio": uniform(0, 1),
            },
            {
                "penalty": [None],
                "solver": ["lbfgs", "newton-cg", "sag", "saga"],
            },
        ],
    ),
    # ===== MLP CLASSIFIER =====
    "mlp": (
        MLPClassifier(max_iter=5000, random_state=42),
        {
            "hidden_layer_sizes": [(50,), (100,), (50, 50), (100, 50), (100, 100)],
            "activation": ["tanh", "relu"],
            "solver": ["sgd", "adam"],
            "alpha": loguniform(1e-5, 1e-1),
            "learning_rate": ["constant", "invscaling", "adaptive"],
            "learning_rate_init": loguniform(1e-4, 1e-2),
        },
    ),
    # ===== LINEAR MODEL =====
    "linear": (
        SGDClassifier(max_iter=5000, random_state=42),
        {
            "loss": ["log_loss", "modified_huber"],
            "penalty": ["l2", "l1", "elasticnet"],
            "alpha": loguniform(1e-6, 1e-1),
            "l1_ratio": uniform(0, 1),
            "learning_rate": ["optimal", "invscaling", "adaptive"],
            "eta0": loguniform(1e-4, 1e0),
        },
    ),
    # ===== K-NEAREST NEIGHBORS =====
    "knn": (
        KNeighborsClassifier(),
        {
            "n_neighbors": randint(1, 20),
            "weights": ["uniform", "distance"],
            "algorithm": ["auto", "kd_tree", "brute"],
            "p": [1, 2],
            "leaf_size": randint(10, 50),
            "metric": ["minkowski", "euclidean", "manhattan"],
        },
    ),
    # ===== GRADIENT BOOSTING CLASSIFIER =====
    "gbdt": (
        GradientBoostingClassifier(random_state=42),
        {
            "n_estimators": randint(100, 1000),
            "learning_rate": loguniform(0.01, 1.0),
            "max_depth": randint(3, 10),
            "min_samples_split": randint(2, 20),
            "min_samples_leaf": randint(1, 20),
            "subsample": uniform(0.6, 0.4),
            "max_features": ["sqrt", "log2", None],
        },
    ),
}

# %%
best_models = {}
folds = 3
factor = 2

for name, (model, param_dist) in models_and_params.items():
    print("=" * 40 + f"\n{name}\n" + "=" * 40)
    stratified_cv = StratifiedKFold(n_splits=folds, shuffle=True, random_state=42)
    search = HalvingRandomSearchCV(
        estimator=model,
        param_distributions=param_dist,
        cv=stratified_cv,
        scoring="roc_auc",
        n_jobs=-1,
        random_state=42,
        verbose=3,
        factor=factor,
        min_resources=int(len(X_train) / factor**5),
        max_resources=int(len(X_train) * 0.3),
    )

    search.fit(X_train, y_train[config.target_column])
    best_models[name] = search.best_estimator_
    print(f"{name} best score: {search.best_score_:.4f}")
    print("\nBest Hyperparameters Found:")
    print(search.best_params_)
# Out:
# ========================================
# logreg
# ========================================
# n_iterations: 4
# n_required_iterations: 4
# n_possible_iterations: 4
# min_resources_: 21093
# max_resources_: 202500
# aggressive_elimination: False
# factor: 2
# ----------
# iter: 0
# n_candidates: 9
# n_resources: 21093
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 3/3] END penalty=None, solver=lbfgs;, score=(train=0.940, test=0.941) total time=   0.1s
# [CV 1/3] END penalty=None, solver=lbfgs;, score=(train=0.938, test=0.927) total time=   0.2s
# [CV 2/3] END penalty=None, solver=lbfgs;, score=(train=0.941, test=0.930) total time=   0.1s
# [CV 3/3] END C=0.08632008168602544, penalty=l2, solver=sag;, score=(train=0.939, test=0.940) total time=   1.9s
# [CV 1/3] END C=0.022310108018679227, l1_ratio=0.8661761457749352, penalty=elasticnet, solver=saga;, score=(train=0.931, test=0.924) total time=   0.7s
# [CV 1/3] END C=0.08632008168602544, penalty=l2, solver=sag;, score=(train=0.936, test=0.927) total time=   1.7s
# [CV 2/3] END C=0.08632008168602544, penalty=l2, solver=sag;, score=(train=0.940, test=0.931) total time=   1.9s
# [CV 2/3] END C=0.022310108018679227, l1_ratio=0.8661761457749352, penalty=elasticnet, solver=saga;, score=(train=0.935, test=0.929) total time=   1.7s
# [CV 3/3] END C=0.022310108018679227, l1_ratio=0.8661761457749352, penalty=elasticnet, solver=saga;, score=(train=0.935, test=0.935) total time=   1.2s
# [CV 3/3] END penalty=None, solver=saga;, score=(train=0.940, test=0.941) total time=   7.4s
# [CV 1/3] END penalty=None, solver=sag;, score=(train=0.938, test=0.927) total time=   7.6s
# [CV 1/3] END C=0.0218006515864352, penalty=l1, solver=saga;, score=(train=0.931, test=0.924) total time=   1.1s
# [CV 1/3] END C=601.5308718396454, l1_ratio=0.1834347898661638, penalty=elasticnet, solver=saga;, score=(train=0.938, test=0.927) total time=  13.7s
# [CV 2/3] END C=0.0218006515864352, penalty=l1, solver=saga;, score=(train=0.935, test=0.928) total time=   1.3s
# [CV 1/3] END penalty=None, solver=newton-cg;, score=(train=0.938, test=0.927) total time=   0.1s
# [CV 1/3] END penalty=None, solver=saga;, score=(train=0.938, test=0.927) total time=  11.8s
# [CV 3/3] END C=0.0218006515864352, penalty=l1, solver=saga;, score=(train=0.935, test=0.935) total time=   1.1s
# [CV 2/3] END penalty=None, solver=newton-cg;, score=(train=0.941, test=0.930) total time=   0.1s
# [CV 3/3] END penalty=None, solver=newton-cg;, score=(train=0.940, test=0.941) total time=   0.1s
# [CV 2/3] END penalty=None, solver=saga;, score=(train=0.941, test=0.930) total time=  12.0s
# [CV 3/3] END C=601.5308718396454, l1_ratio=0.1834347898661638, penalty=elasticnet, solver=saga;, score=(train=0.940, test=0.941) total time=  15.8s
# [CV 1/3] END C=0.010108171343846388, penalty=l1, solver=saga;, score=(train=0.924, test=0.919) total time=   0.7s
# [CV 2/3] END C=0.010108171343846388, penalty=l1, solver=saga;, score=(train=0.927, test=0.921) total time=   0.6s
# [CV 3/3] END C=0.010108171343846388, penalty=l1, solver=saga;, score=(train=0.926, test=0.925) total time=   0.5s
# [CV 3/3] END penalty=None, solver=sag;, score=(train=0.940, test=0.941) total time=   5.2s
# [CV 2/3] END penalty=None, solver=sag;, score=(train=0.941, test=0.930) total time=  15.0s
# [CV 2/3] END C=601.5308718396454, l1_ratio=0.1834347898661638, penalty=elasticnet, solver=saga;, score=(train=0.941, test=0.930) total time=  21.5s
# ----------
# iter: 1
# n_candidates: 5
# n_resources: 42186
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV 2/3] END penalty=None, solver=lbfgs;, score=(train=0.940, test=0.934) total time=   0.3s
# [CV 1/3] END penalty=None, solver=lbfgs;, score=(train=0.939, test=0.934) total time=   0.3s
# [CV 3/3] END penalty=None, solver=lbfgs;, score=(train=0.941, test=0.939) total time=   0.3s
# [CV 1/3] END penalty=None, solver=newton-cg;, score=(train=0.939, test=0.935) total time=   0.4s
# [CV 2/3] END penalty=None, solver=newton-cg;, score=(train=0.940, test=0.934) total time=   0.3s
# [CV 3/3] END penalty=None, solver=newton-cg;, score=(train=0.941, test=0.939) total time=   0.2s
# [CV 3/3] END penalty=None, solver=saga;, score=(train=0.941, test=0.939) total time=  24.9s
# [CV 2/3] END penalty=None, solver=saga;, score=(train=0.940, test=0.934) total time=  25.1s
# [CV 3/3] END C=601.5308718396454, l1_ratio=0.1834347898661638, penalty=elasticnet, solver=saga;, score=(train=0.941, test=0.939) total time=  34.8s
# [CV 2/3] END C=601.5308718396454, l1_ratio=0.1834347898661638, penalty=elasticnet, solver=saga;, score=(train=0.940, test=0.934) total time=  35.4s
# [CV 3/3] END penalty=None, solver=sag;, score=(train=0.941, test=0.939) total time=  13.9s
# [CV 2/3] END penalty=None, solver=sag;, score=(train=0.940, test=0.934) total time=  40.7s
# [CV 1/3] END penalty=None, solver=sag;, score=(train=0.939, test=0.935) total time=  49.3s
# [CV 1/3] END penalty=None, solver=saga;, score=(train=0.939, test=0.935) total time=  54.2s
# [CV 1/3] END C=601.5308718396454, l1_ratio=0.1834347898661638, penalty=elasticnet, solver=saga;, score=(train=0.939, test=0.935) total time= 1.2min
# ----------
# iter: 2
# n_candidates: 3
# n_resources: 84372
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# [CV 3/3] END penalty=None, solver=sag;, score=(train=0.940, test=0.938) total time=  20.8s
# [CV 2/3] END penalty=None, solver=sag;, score=(train=0.939, test=0.935) total time=  30.0s
# [CV 2/3] END penalty=None, solver=saga;, score=(train=0.939, test=0.935) total time=  39.6s
# [CV 3/3] END penalty=None, solver=saga;, score=(train=0.940, test=0.938) total time=  41.7s
# [CV 2/3] END C=601.5308718396454, l1_ratio=0.1834347898661638, penalty=elasticnet, solver=saga;, score=(train=0.939, test=0.935) total time= 1.0min
# [CV 3/3] END C=601.5308718396454, l1_ratio=0.1834347898661638, penalty=elasticnet, solver=saga;, score=(train=0.940, test=0.938) total time=  42.3s
# [CV 1/3] END penalty=None, solver=sag;, score=(train=0.938, test=0.936) total time= 1.5min
# [CV 1/3] END penalty=None, solver=saga;, score=(train=0.938, test=0.936) total time= 1.8min
# [CV 1/3] END C=601.5308718396454, l1_ratio=0.1834347898661638, penalty=elasticnet, solver=saga;, score=(train=0.938, test=0.936) total time= 2.4min
# ----------
# iter: 3
# n_candidates: 2
# n_resources: 168744
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# [CV 1/3] END penalty=None, solver=saga;, score=(train=0.937, test=0.939) total time=  40.0s
# [CV 2/3] END penalty=None, solver=saga;, score=(train=0.939, test=0.936) total time=  51.7s
# [CV 1/3] END C=601.5308718396454, l1_ratio=0.1834347898661638, penalty=elasticnet, solver=saga;, score=(train=0.937, test=0.939) total time=  54.6s
# [CV 3/3] END penalty=None, solver=saga;, score=(train=0.940, test=0.938) total time= 1.0min
# [CV 2/3] END C=601.5308718396454, l1_ratio=0.1834347898661638, penalty=elasticnet, solver=saga;, score=(train=0.939, test=0.936) total time= 1.1min
# [CV 3/3] END C=601.5308718396454, l1_ratio=0.1834347898661638, penalty=elasticnet, solver=saga;, score=(train=0.940, test=0.938) total time= 1.3min
# logreg best score: 0.9377
#
# Best Hyperparameters Found:
# {'C': 601.5308718396454, 'l1_ratio': 0.1834347898661638, 'penalty': 'elasticnet', 'solver': 'saga'}
# ========================================
# mlp
# ========================================
# n_iterations: 4
# n_required_iterations: 4
# n_possible_iterations: 4
# min_resources_: 21093
# max_resources_: 202500
# aggressive_elimination: False
# factor: 2
# ----------
# iter: 0
# n_candidates: 9
# n_resources: 21093
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 2/3] END activation=tanh, alpha=2.511306167739e-05, hidden_layer_sizes=(50, 50), learning_rate=constant, learning_rate_init=0.0015930522616241021, solver=adam;, score=(train=1.000, test=0.927) total time=   7.4s
# [CV 2/3] END activation=tanh, alpha=0.015352246941973482, hidden_layer_sizes=(50, 50), learning_rate=constant, learning_rate_init=0.0015620693675639863, solver=adam;, score=(train=1.000, test=0.925) total time=   8.3s
# [CV 3/3] END activation=tanh, alpha=2.511306167739e-05, hidden_layer_sizes=(50, 50), learning_rate=constant, learning_rate_init=0.0015930522616241021, solver=adam;, score=(train=1.000, test=0.920) total time=  10.5s
# [CV 1/3] END activation=tanh, alpha=0.015352246941973482, hidden_layer_sizes=(50, 50), learning_rate=constant, learning_rate_init=0.0015620693675639863, solver=adam;, score=(train=1.000, test=0.921) total time=  10.7s
# [CV 1/3] END activation=tanh, alpha=2.511306167739e-05, hidden_layer_sizes=(50, 50), learning_rate=constant, learning_rate_init=0.0015930522616241021, solver=adam;, score=(train=1.000, test=0.913) total time=  10.8s
# [CV 3/3] END activation=tanh, alpha=0.015352246941973482, hidden_layer_sizes=(50, 50), learning_rate=constant, learning_rate_init=0.0015620693675639863, solver=adam;, score=(train=1.000, test=0.923) total time=  11.0s
# [CV 1/3] END activation=relu, alpha=5.415244119402538e-05, hidden_layer_sizes=(100, 50), learning_rate=invscaling, learning_rate_init=0.0011207606211860567, solver=adam;, score=(train=1.000, test=0.920) total time=   8.8s
# [CV 2/3] END activation=relu, alpha=5.415244119402538e-05, hidden_layer_sizes=(100, 50), learning_rate=invscaling, learning_rate_init=0.0011207606211860567, solver=adam;, score=(train=1.000, test=0.924) total time=   7.8s
# [CV 3/3] END activation=relu, alpha=5.415244119402538e-05, hidden_layer_sizes=(100, 50), learning_rate=invscaling, learning_rate_init=0.0011207606211860567, solver=adam;, score=(train=1.000, test=0.930) total time=   9.4s
# [CV 1/3] END activation=relu, alpha=0.0002920433847181409, hidden_layer_sizes=(50, 50), learning_rate=adaptive, learning_rate_init=0.009256818992066877, solver=sgd;, score=(train=1.000, test=0.924) total time=  20.9s
# [CV 2/3] END activation=tanh, alpha=1.2087541473056957e-05, hidden_layer_sizes=(100,), learning_rate=invscaling, learning_rate_init=0.00026587543983272726, solver=adam;, score=(train=1.000, test=0.926) total time=  40.4s
# [CV 2/3] END activation=relu, alpha=0.0002920433847181409, hidden_layer_sizes=(50, 50), learning_rate=adaptive, learning_rate_init=0.009256818992066877, solver=sgd;, score=(train=0.999, test=0.922) total time=  21.3s
# [CV 1/3] END activation=tanh, alpha=1.2087541473056957e-05, hidden_layer_sizes=(100,), learning_rate=invscaling, learning_rate_init=0.00026587543983272726, solver=adam;, score=(train=1.000, test=0.924) total time=  44.4s
# [CV 3/3] END activation=tanh, alpha=1.2087541473056957e-05, hidden_layer_sizes=(100,), learning_rate=invscaling, learning_rate_init=0.00026587543983272726, solver=adam;, score=(train=1.000, test=0.928) total time=  37.6s
# [CV 1/3] END activation=tanh, alpha=0.07286653737491042, hidden_layer_sizes=(100,), learning_rate=invscaling, learning_rate_init=0.0004066563313514797, solver=sgd;, score=(train=0.528, test=0.536) total time=   3.7s
# [CV 2/3] END activation=tanh, alpha=0.07286653737491042, hidden_layer_sizes=(100,), learning_rate=invscaling, learning_rate_init=0.0004066563313514797, solver=sgd;, score=(train=0.539, test=0.548) total time=   3.1s
# [CV 3/3] END activation=tanh, alpha=0.07286653737491042, hidden_layer_sizes=(100,), learning_rate=invscaling, learning_rate_init=0.0004066563313514797, solver=sgd;, score=(train=0.538, test=0.558) total time=   2.3s
# [CV 3/3] END activation=relu, alpha=0.0002920433847181409, hidden_layer_sizes=(50, 50), learning_rate=adaptive, learning_rate_init=0.009256818992066877, solver=sgd;, score=(train=0.998, test=0.926) total time=  20.1s
# [CV 1/3] END activation=relu, alpha=0.005456725485601475, hidden_layer_sizes=(100, 50), learning_rate=adaptive, learning_rate_init=0.0016595613641357263, solver=adam;, score=(train=0.999, test=0.914) total time=   6.0s
# [CV 3/3] END activation=tanh, alpha=0.0001461896279370495, hidden_layer_sizes=(50, 50), learning_rate=adaptive, learning_rate_init=0.00019010245319870352, solver=adam;, score=(train=0.999, test=0.920) total time=  43.9s
# [CV 2/3] END activation=tanh, alpha=0.0001461896279370495, hidden_layer_sizes=(50, 50), learning_rate=adaptive, learning_rate_init=0.00019010245319870352, solver=adam;, score=(train=1.000, test=0.916) total time=  55.1s
# [CV 2/3] END activation=relu, alpha=0.005456725485601475, hidden_layer_sizes=(100, 50), learning_rate=adaptive, learning_rate_init=0.0016595613641357263, solver=adam;, score=(train=1.000, test=0.925) total time=   6.6s
# [CV 3/3] END activation=relu, alpha=0.005456725485601475, hidden_layer_sizes=(100, 50), learning_rate=adaptive, learning_rate_init=0.0016595613641357263, solver=adam;, score=(train=0.999, test=0.929) total time=   5.8s
# [CV 1/3] END activation=tanh, alpha=0.0001461896279370495, hidden_layer_sizes=(50, 50), learning_rate=adaptive, learning_rate_init=0.00019010245319870352, solver=adam;, score=(train=1.000, test=0.913) total time=  57.3s
# [CV 3/3] END activation=tanh, alpha=0.027527173929429397, hidden_layer_sizes=(100, 100), learning_rate=constant, learning_rate_init=0.00013492834268013249, solver=adam;, score=(train=0.996, test=0.935) total time=  42.3s
# [CV 1/3] END activation=tanh, alpha=0.027527173929429397, hidden_layer_sizes=(100, 100), learning_rate=constant, learning_rate_init=0.00013492834268013249, solver=adam;, score=(train=0.993, test=0.931) total time=  46.4s
# [CV 2/3] END activation=tanh, alpha=0.027527173929429397, hidden_layer_sizes=(100, 100), learning_rate=constant, learning_rate_init=0.00013492834268013249, solver=adam;, score=(train=0.995, test=0.930) total time=  50.7s
# ----------
# iter: 1
# n_candidates: 5
# n_resources: 42186
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV 3/3] END activation=relu, alpha=0.005456725485601475, hidden_layer_sizes=(100, 50), learning_rate=adaptive, learning_rate_init=0.0016595613641357263, solver=adam;, score=(train=1.000, test=0.929) total time=  16.0s
# [CV 2/3] END activation=relu, alpha=0.005456725485601475, hidden_layer_sizes=(100, 50), learning_rate=adaptive, learning_rate_init=0.0016595613641357263, solver=adam;, score=(train=1.000, test=0.930) total time=  18.5s
# [CV 1/3] END activation=relu, alpha=5.415244119402538e-05, hidden_layer_sizes=(100, 50), learning_rate=invscaling, learning_rate_init=0.0011207606211860567, solver=adam;, score=(train=1.000, test=0.926) total time=  18.9s
# [CV 1/3] END activation=relu, alpha=0.005456725485601475, hidden_layer_sizes=(100, 50), learning_rate=adaptive, learning_rate_init=0.0016595613641357263, solver=adam;, score=(train=1.000, test=0.926) total time=  20.1s
# [CV 2/3] END activation=relu, alpha=5.415244119402538e-05, hidden_layer_sizes=(100, 50), learning_rate=invscaling, learning_rate_init=0.0011207606211860567, solver=adam;, score=(train=1.000, test=0.924) total time=  26.2s
# [CV 3/3] END activation=relu, alpha=5.415244119402538e-05, hidden_layer_sizes=(100, 50), learning_rate=invscaling, learning_rate_init=0.0011207606211860567, solver=adam;, score=(train=1.000, test=0.932) total time=  22.4s
# [CV 1/3] END activation=relu, alpha=0.0002920433847181409, hidden_layer_sizes=(50, 50), learning_rate=adaptive, learning_rate_init=0.009256818992066877, solver=sgd;, score=(train=0.995, test=0.931) total time=  38.8s
# [CV 3/3] END activation=relu, alpha=0.0002920433847181409, hidden_layer_sizes=(50, 50), learning_rate=adaptive, learning_rate_init=0.009256818992066877, solver=sgd;, score=(train=0.995, test=0.932) total time=  43.5s
# [CV 2/3] END activation=relu, alpha=0.0002920433847181409, hidden_layer_sizes=(50, 50), learning_rate=adaptive, learning_rate_init=0.009256818992066877, solver=sgd;, score=(train=0.998, test=0.925) total time=  50.9s
# [CV 2/3] END activation=tanh, alpha=0.027527173929429397, hidden_layer_sizes=(100, 100), learning_rate=constant, learning_rate_init=0.00013492834268013249, solver=adam;, score=(train=0.972, test=0.954) total time=  28.0s
# [CV 1/3] END activation=tanh, alpha=1.2087541473056957e-05, hidden_layer_sizes=(100,), learning_rate=invscaling, learning_rate_init=0.00026587543983272726, solver=adam;, score=(train=0.998, test=0.928) total time= 1.1min
# [CV 2/3] END activation=tanh, alpha=1.2087541473056957e-05, hidden_layer_sizes=(100,), learning_rate=invscaling, learning_rate_init=0.00026587543983272726, solver=adam;, score=(train=0.998, test=0.928) total time= 1.1min
# [CV 1/3] END activation=tanh, alpha=0.027527173929429397, hidden_layer_sizes=(100, 100), learning_rate=constant, learning_rate_init=0.00013492834268013249, solver=adam;, score=(train=0.983, test=0.947) total time= 1.0min
# [CV 3/3] END activation=tanh, alpha=1.2087541473056957e-05, hidden_layer_sizes=(100,), learning_rate=invscaling, learning_rate_init=0.00026587543983272726, solver=adam;, score=(train=0.998, test=0.924) total time= 1.2min
# [CV 3/3] END activation=tanh, alpha=0.027527173929429397, hidden_layer_sizes=(100, 100), learning_rate=constant, learning_rate_init=0.00013492834268013249, solver=adam;, score=(train=0.987, test=0.944) total time= 1.1min
# ----------
# iter: 2
# n_candidates: 3
# n_resources: 84372
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# [CV 3/3] END activation=relu, alpha=0.005456725485601475, hidden_layer_sizes=(100, 50), learning_rate=adaptive, learning_rate_init=0.0016595613641357263, solver=adam;, score=(train=0.996, test=0.932) total time=  35.1s
# [CV 2/3] END activation=relu, alpha=0.005456725485601475, hidden_layer_sizes=(100, 50), learning_rate=adaptive, learning_rate_init=0.0016595613641357263, solver=adam;, score=(train=0.997, test=0.928) total time=  42.1s
# [CV 2/3] END activation=tanh, alpha=0.027527173929429397, hidden_layer_sizes=(100, 100), learning_rate=constant, learning_rate_init=0.00013492834268013249, solver=adam;, score=(train=0.968, test=0.957) total time=  48.9s
# [CV 1/3] END activation=relu, alpha=0.005456725485601475, hidden_layer_sizes=(100, 50), learning_rate=adaptive, learning_rate_init=0.0016595613641357263, solver=adam;, score=(train=0.998, test=0.929) total time=  50.6s
# [CV 3/3] END activation=relu, alpha=0.0002920433847181409, hidden_layer_sizes=(50, 50), learning_rate=adaptive, learning_rate_init=0.009256818992066877, solver=sgd;, score=(train=0.985, test=0.944) total time= 1.1min
# [CV 1/3] END activation=relu, alpha=0.0002920433847181409, hidden_layer_sizes=(50, 50), learning_rate=adaptive, learning_rate_init=0.009256818992066877, solver=sgd;, score=(train=0.985, test=0.941) total time= 1.2min
# [CV 2/3] END activation=relu, alpha=0.0002920433847181409, hidden_layer_sizes=(50, 50), learning_rate=adaptive, learning_rate_init=0.009256818992066877, solver=sgd;, score=(train=0.988, test=0.940) total time= 1.4min
# [CV 1/3] END activation=tanh, alpha=0.027527173929429397, hidden_layer_sizes=(100, 100), learning_rate=constant, learning_rate_init=0.00013492834268013249, solver=adam;, score=(train=0.973, test=0.956) total time= 1.6min
# [CV 3/3] END activation=tanh, alpha=0.027527173929429397, hidden_layer_sizes=(100, 100), learning_rate=constant, learning_rate_init=0.00013492834268013249, solver=adam;, score=(train=0.973, test=0.954) total time= 1.4min
# ----------
# iter: 3
# n_candidates: 2
# n_resources: 168744
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# [CV 2/3] END activation=tanh, alpha=0.027527173929429397, hidden_layer_sizes=(100, 100), learning_rate=constant, learning_rate_init=0.00013492834268013249, solver=adam;, score=(train=0.965, test=0.959) total time= 1.0min
# [CV 3/3] END activation=tanh, alpha=0.027527173929429397, hidden_layer_sizes=(100, 100), learning_rate=constant, learning_rate_init=0.00013492834268013249, solver=adam;, score=(train=0.966, test=0.960) total time= 1.2min
# [CV 1/3] END activation=tanh, alpha=0.027527173929429397, hidden_layer_sizes=(100, 100), learning_rate=constant, learning_rate_init=0.00013492834268013249, solver=adam;, score=(train=0.965, test=0.961) total time= 1.3min
# [CV 1/3] END activation=relu, alpha=0.0002920433847181409, hidden_layer_sizes=(50, 50), learning_rate=adaptive, learning_rate_init=0.009256818992066877, solver=sgd;, score=(train=0.976, test=0.955) total time= 1.5min
# [CV 3/3] END activation=relu, alpha=0.0002920433847181409, hidden_layer_sizes=(50, 50), learning_rate=adaptive, learning_rate_init=0.009256818992066877, solver=sgd;, score=(train=0.976, test=0.953) total time= 1.5min
# [CV 2/3] END activation=relu, alpha=0.0002920433847181409, hidden_layer_sizes=(50, 50), learning_rate=adaptive, learning_rate_init=0.009256818992066877, solver=sgd;, score=(train=0.978, test=0.951) total time= 1.7min
# mlp best score: 0.9600
#
# Best Hyperparameters Found:
# {'activation': 'tanh', 'alpha': 0.027527173929429397, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'constant', 'learning_rate_init': 0.00013492834268013249, 'solver': 'adam'}
# ========================================
# linear
# ========================================
# n_iterations: 4
# n_required_iterations: 4
# n_possible_iterations: 4
# min_resources_: 21093
# max_resources_: 202500
# aggressive_elimination: False
# factor: 2
# ----------
# iter: 0
# n_candidates: 9
# n_resources: 21093
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END alpha=7.459343285726558e-05, eta0=0.6351221010640696, l1_ratio=0.7319939418114051, learning_rate=optimal, loss=log_loss, penalty=elasticnet;, score=(train=0.931, test=0.919) total time=   0.2s
# [CV 2/3] END alpha=1.2674255898937221e-06, eta0=0.7579479953348001, l1_ratio=0.8324426408004217, learning_rate=invscaling, loss=modified_huber, penalty=l2;, score=(train=0.934, test=0.927) total time=   0.1s
# [CV 1/3] END alpha=0.0012229467525390605, eta0=0.02796485951606245, l1_ratio=0.007066305219717406, learning_rate=optimal, loss=log_loss, penalty=elasticnet;, score=(train=0.933, test=0.925) total time=   0.1s
# [CV 2/3] END alpha=0.0012229467525390605, eta0=0.02796485951606245, l1_ratio=0.007066305219717406, learning_rate=optimal, loss=log_loss, penalty=elasticnet;, score=(train=0.937, test=0.928) total time=   0.1s
# [CV 3/3] END alpha=0.0012229467525390605, eta0=0.02796485951606245, l1_ratio=0.007066305219717406, learning_rate=optimal, loss=log_loss, penalty=elasticnet;, score=(train=0.937, test=0.939) total time=   0.1s
# [CV 1/3] END alpha=1.2674255898937221e-06, eta0=0.7579479953348001, l1_ratio=0.8324426408004217, learning_rate=invscaling, loss=modified_huber, penalty=l2;, score=(train=0.931, test=0.923) total time=   0.1s
# [CV 3/3] END alpha=7.459343285726558e-05, eta0=0.6351221010640696, l1_ratio=0.7319939418114051, learning_rate=optimal, loss=log_loss, penalty=elasticnet;, score=(train=0.933, test=0.933) total time=   0.2s
# [CV 2/3] END alpha=0.00016949768237884723, eta0=0.00025113061677390025, l1_ratio=0.45924889196586716, learning_rate=optimal, loss=modified_huber, penalty=elasticnet;, score=(train=0.932, test=0.919) total time=   0.3s
# [CV 1/3] END alpha=0.00016949768237884723, eta0=0.00025113061677390025, l1_ratio=0.45924889196586716, learning_rate=optimal, loss=modified_huber, penalty=elasticnet;, score=(train=0.922, test=0.908) total time=   0.3s
# [CV 2/3] END alpha=7.459343285726558e-05, eta0=0.6351221010640696, l1_ratio=0.7319939418114051, learning_rate=optimal, loss=log_loss, penalty=elasticnet;, score=(train=0.932, test=0.924) total time=   0.3s
# [CV 1/3] END alpha=0.0011462107403425038, eta0=0.0003613894271216529, l1_ratio=0.29214464853521815, learning_rate=adaptive, loss=modified_huber, penalty=l1;, score=(train=0.936, test=0.927) total time=   0.2s
# [CV 3/3] END alpha=1.2674255898937221e-06, eta0=0.7579479953348001, l1_ratio=0.8324426408004217, learning_rate=invscaling, loss=modified_huber, penalty=l2;, score=(train=0.938, test=0.937) total time=   0.1s
# [CV 3/3] END alpha=0.00016949768237884723, eta0=0.00025113061677390025, l1_ratio=0.45924889196586716, learning_rate=optimal, loss=modified_huber, penalty=elasticnet;, score=(train=0.921, test=0.927) total time=   0.3s
# [CV 2/3] END alpha=0.0011462107403425038, eta0=0.0003613894271216529, l1_ratio=0.29214464853521815, learning_rate=adaptive, loss=modified_huber, penalty=l1;, score=(train=0.939, test=0.931) total time=   0.1s
# [CV 1/3] END alpha=0.008431013932082471, eta0=0.0006290644294586153, l1_ratio=0.5142344384136116, learning_rate=optimal, loss=log_loss, penalty=l2;, score=(train=0.929, test=0.924) total time=   0.1s
# [CV 3/3] END alpha=0.0011462107403425038, eta0=0.0003613894271216529, l1_ratio=0.29214464853521815, learning_rate=adaptive, loss=modified_huber, penalty=l1;, score=(train=0.939, test=0.940) total time=   0.1s
# [CV 2/3] END alpha=0.008431013932082471, eta0=0.0006290644294586153, l1_ratio=0.5142344384136116, learning_rate=optimal, loss=log_loss, penalty=l2;, score=(train=0.935, test=0.928) total time=   0.1s
# [CV 3/3] END alpha=0.008431013932082471, eta0=0.0006290644294586153, l1_ratio=0.5142344384136116, learning_rate=optimal, loss=log_loss, penalty=l2;, score=(train=0.933, test=0.934) total time=   0.1s
# [CV 1/3] END alpha=0.00109074758351577, eta0=0.00048094619675015767, l1_ratio=0.06505159298527952, learning_rate=optimal, loss=modified_huber, penalty=l1;, score=(train=0.936, test=0.925) total time=   0.1s
# [CV 2/3] END alpha=0.00109074758351577, eta0=0.00048094619675015767, l1_ratio=0.06505159298527952, learning_rate=optimal, loss=modified_huber, penalty=l1;, score=(train=0.937, test=0.928) total time=   0.1s
# [CV 3/3] END alpha=0.00109074758351577, eta0=0.00048094619675015767, l1_ratio=0.06505159298527952, learning_rate=optimal, loss=modified_huber, penalty=l1;, score=(train=0.936, test=0.937) total time=   0.1s
# [CV 1/3] END alpha=0.01101505679026964, eta0=0.001653693718282443, l1_ratio=0.09767211400638387, learning_rate=adaptive, loss=modified_huber, penalty=elasticnet;, score=(train=0.936, test=0.927) total time=   0.2s
# [CV 2/3] END alpha=0.01101505679026964, eta0=0.001653693718282443, l1_ratio=0.09767211400638387, learning_rate=adaptive, loss=modified_huber, penalty=elasticnet;, score=(train=0.939, test=0.931) total time=   0.1s
# [CV 3/3] END alpha=0.01101505679026964, eta0=0.001653693718282443, l1_ratio=0.09767211400638387, learning_rate=adaptive, loss=modified_huber, penalty=elasticnet;, score=(train=0.939, test=0.939) total time=   0.1s
# [CV 1/3] END alpha=0.0011219752813215707, eta0=0.215168972980833, l1_ratio=0.17336465350777208, learning_rate=optimal, loss=modified_huber, penalty=l1;, score=(train=0.936, test=0.924) total time=   0.1s
# [CV 2/3] END alpha=0.0011219752813215707, eta0=0.215168972980833, l1_ratio=0.17336465350777208, learning_rate=optimal, loss=modified_huber, penalty=l1;, score=(train=0.931, test=0.926) total time=   0.1s
# [CV 3/3] END alpha=0.0011219752813215707, eta0=0.215168972980833, l1_ratio=0.17336465350777208, learning_rate=optimal, loss=modified_huber, penalty=l1;, score=(train=0.933, test=0.932) total time=   0.1s
# ----------
# iter: 1
# n_candidates: 5
# n_resources: 42186
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV 1/3] END alpha=1.2674255898937221e-06, eta0=0.7579479953348001, l1_ratio=0.8324426408004217, learning_rate=invscaling, loss=modified_huber, penalty=l2;, score=(train=0.939, test=0.935) total time=   0.1s
# [CV 2/3] END alpha=1.2674255898937221e-06, eta0=0.7579479953348001, l1_ratio=0.8324426408004217, learning_rate=invscaling, loss=modified_huber, penalty=l2;, score=(train=0.936, test=0.930) total time=   0.1s
# [CV 3/3] END alpha=1.2674255898937221e-06, eta0=0.7579479953348001, l1_ratio=0.8324426408004217, learning_rate=invscaling, loss=modified_huber, penalty=l2;, score=(train=0.939, test=0.938) total time=   0.1s
# [CV 1/3] END alpha=0.00109074758351577, eta0=0.00048094619675015767, l1_ratio=0.06505159298527952, learning_rate=optimal, loss=modified_huber, penalty=l1;, score=(train=0.933, test=0.928) total time=   0.3s
# [CV 2/3] END alpha=0.00109074758351577, eta0=0.00048094619675015767, l1_ratio=0.06505159298527952, learning_rate=optimal, loss=modified_huber, penalty=l1;, score=(train=0.935, test=0.931) total time=   0.3s
# [CV 1/3] END alpha=0.0012229467525390605, eta0=0.02796485951606245, l1_ratio=0.007066305219717406, learning_rate=optimal, loss=log_loss, penalty=elasticnet;, score=(train=0.936, test=0.932) total time=   0.2s
# [CV 3/3] END alpha=0.00109074758351577, eta0=0.00048094619675015767, l1_ratio=0.06505159298527952, learning_rate=optimal, loss=modified_huber, penalty=l1;, score=(train=0.934, test=0.931) total time=   0.3s
# [CV 2/3] END alpha=0.0012229467525390605, eta0=0.02796485951606245, l1_ratio=0.007066305219717406, learning_rate=optimal, loss=log_loss, penalty=elasticnet;, score=(train=0.938, test=0.934) total time=   0.2s
# [CV 3/3] END alpha=0.0012229467525390605, eta0=0.02796485951606245, l1_ratio=0.007066305219717406, learning_rate=optimal, loss=log_loss, penalty=elasticnet;, score=(train=0.939, test=0.935) total time=   0.1s
# [CV 1/3] END alpha=0.0011462107403425038, eta0=0.0003613894271216529, l1_ratio=0.29214464853521815, learning_rate=adaptive, loss=modified_huber, penalty=l1;, score=(train=0.938, test=0.933) total time=   0.3s
# [CV 2/3] END alpha=0.0011462107403425038, eta0=0.0003613894271216529, l1_ratio=0.29214464853521815, learning_rate=adaptive, loss=modified_huber, penalty=l1;, score=(train=0.939, test=0.934) total time=   0.3s
# [CV 3/3] END alpha=0.0011462107403425038, eta0=0.0003613894271216529, l1_ratio=0.29214464853521815, learning_rate=adaptive, loss=modified_huber, penalty=l1;, score=(train=0.940, test=0.937) total time=   0.3s
# [CV 1/3] END alpha=0.01101505679026964, eta0=0.001653693718282443, l1_ratio=0.09767211400638387, learning_rate=adaptive, loss=modified_huber, penalty=elasticnet;, score=(train=0.937, test=0.933) total time=   0.3s
# [CV 2/3] END alpha=0.01101505679026964, eta0=0.001653693718282443, l1_ratio=0.09767211400638387, learning_rate=adaptive, loss=modified_huber, penalty=elasticnet;, score=(train=0.938, test=0.934) total time=   0.3s
# [CV 3/3] END alpha=0.01101505679026964, eta0=0.001653693718282443, l1_ratio=0.09767211400638387, learning_rate=adaptive, loss=modified_huber, penalty=elasticnet;, score=(train=0.939, test=0.936) total time=   0.3s
# ----------
# iter: 2
# n_candidates: 3
# n_resources: 84372
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# [CV 1/3] END alpha=1.2674255898937221e-06, eta0=0.7579479953348001, l1_ratio=0.8324426408004217, learning_rate=invscaling, loss=modified_huber, penalty=l2;, score=(train=0.936, test=0.934) total time=   0.3s
# [CV 2/3] END alpha=1.2674255898937221e-06, eta0=0.7579479953348001, l1_ratio=0.8324426408004217, learning_rate=invscaling, loss=modified_huber, penalty=l2;, score=(train=0.936, test=0.932) total time=   0.2s
# [CV 3/3] END alpha=1.2674255898937221e-06, eta0=0.7579479953348001, l1_ratio=0.8324426408004217, learning_rate=invscaling, loss=modified_huber, penalty=l2;, score=(train=0.936, test=0.933) total time=   0.3s
# [CV 1/3] END alpha=0.01101505679026964, eta0=0.001653693718282443, l1_ratio=0.09767211400638387, learning_rate=adaptive, loss=modified_huber, penalty=elasticnet;, score=(train=0.937, test=0.935) total time=   0.7s
# [CV 2/3] END alpha=0.01101505679026964, eta0=0.001653693718282443, l1_ratio=0.09767211400638387, learning_rate=adaptive, loss=modified_huber, penalty=elasticnet;, score=(train=0.936, test=0.934) total time=   0.7s
# [CV 3/3] END alpha=0.01101505679026964, eta0=0.001653693718282443, l1_ratio=0.09767211400638387, learning_rate=adaptive, loss=modified_huber, penalty=elasticnet;, score=(train=0.938, test=0.935) total time=   0.7s
# [CV 1/3] END alpha=0.0011462107403425038, eta0=0.0003613894271216529, l1_ratio=0.29214464853521815, learning_rate=adaptive, loss=modified_huber, penalty=l1;, score=(train=0.937, test=0.935) total time=   0.6s
# [CV 2/3] END alpha=0.0011462107403425038, eta0=0.0003613894271216529, l1_ratio=0.29214464853521815, learning_rate=adaptive, loss=modified_huber, penalty=l1;, score=(train=0.937, test=0.935) total time=   0.6s
# [CV 3/3] END alpha=0.0011462107403425038, eta0=0.0003613894271216529, l1_ratio=0.29214464853521815, learning_rate=adaptive, loss=modified_huber, penalty=l1;, score=(train=0.939, test=0.936) total time=   0.6s
# ----------
# iter: 3
# n_candidates: 2
# n_resources: 168744
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# [CV 1/3] END alpha=0.01101505679026964, eta0=0.001653693718282443, l1_ratio=0.09767211400638387, learning_rate=adaptive, loss=modified_huber, penalty=elasticnet;, score=(train=0.936, test=0.937) total time=   1.3s
# [CV 1/3] END alpha=0.0011462107403425038, eta0=0.0003613894271216529, l1_ratio=0.29214464853521815, learning_rate=adaptive, loss=modified_huber, penalty=l1;, score=(train=0.937, test=0.938) total time=   1.3s
# [CV 3/3] END alpha=0.01101505679026964, eta0=0.001653693718282443, l1_ratio=0.09767211400638387, learning_rate=adaptive, loss=modified_huber, penalty=elasticnet;, score=(train=0.938, test=0.936) total time=   1.4s
# [CV 2/3] END alpha=0.01101505679026964, eta0=0.001653693718282443, l1_ratio=0.09767211400638387, learning_rate=adaptive, loss=modified_huber, penalty=elasticnet;, score=(train=0.937, test=0.935) total time=   1.5s
# [CV 2/3] END alpha=0.0011462107403425038, eta0=0.0003613894271216529, l1_ratio=0.29214464853521815, learning_rate=adaptive, loss=modified_huber, penalty=l1;, score=(train=0.938, test=0.936) total time=   1.3s
# [CV 3/3] END alpha=0.0011462107403425038, eta0=0.0003613894271216529, l1_ratio=0.29214464853521815, learning_rate=adaptive, loss=modified_huber, penalty=l1;, score=(train=0.939, test=0.937) total time=   1.2s
# linear best score: 0.9369
#
# Best Hyperparameters Found:
# {'alpha': 0.0011462107403425038, 'eta0': 0.0003613894271216529, 'l1_ratio': 0.29214464853521815, 'learning_rate': 'adaptive', 'loss': 'modified_huber', 'penalty': 'l1'}
# ========================================
# knn
# ========================================
# n_iterations: 4
# n_required_iterations: 4
# n_possible_iterations: 4
# min_resources_: 21093
# max_resources_: 202500
# aggressive_elimination: False
# factor: 2
# ----------
# iter: 0
# n_candidates: 9
# n_resources: 21093
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END algorithm=auto, leaf_size=48, metric=euclidean, n_neighbors=19, p=1, weights=uniform;, score=(train=0.946, test=0.919) total time=   0.3s
# [CV 2/3] END algorithm=brute, leaf_size=33, metric=minkowski, n_neighbors=4, p=2, weights=distance;, score=(train=1.000, test=0.857) total time=   0.3s
# [CV 1/3] END algorithm=brute, leaf_size=33, metric=minkowski, n_neighbors=4, p=2, weights=distance;, score=(train=1.000, test=0.847) total time=   0.4s
# [CV 3/3] END algorithm=auto, leaf_size=48, metric=euclidean, n_neighbors=19, p=1, weights=uniform;, score=(train=0.952, test=0.916) total time=   0.4s
# [CV 2/3] END algorithm=auto, leaf_size=48, metric=euclidean, n_neighbors=19, p=1, weights=uniform;, score=(train=0.952, test=0.913) total time=   0.4s
# [CV 3/3] END algorithm=brute, leaf_size=33, metric=minkowski, n_neighbors=4, p=2, weights=distance;, score=(train=1.000, test=0.849) total time=   0.3s
# [CV 1/3] END algorithm=brute, leaf_size=31, metric=minkowski, n_neighbors=2, p=2, weights=distance;, score=(train=1.000, test=0.781) total time=   0.2s
# [CV 2/3] END algorithm=brute, leaf_size=31, metric=minkowski, n_neighbors=2, p=2, weights=distance;, score=(train=1.000, test=0.791) total time=   0.4s
# [CV 3/3] END algorithm=brute, leaf_size=31, metric=minkowski, n_neighbors=2, p=2, weights=distance;, score=(train=1.000, test=0.784) total time=   0.3s
# [CV 1/3] END algorithm=kd_tree, leaf_size=47, metric=euclidean, n_neighbors=1, p=2, weights=distance;, score=(train=1.000, test=0.697) total time=   2.1s
# [CV 2/3] END algorithm=kd_tree, leaf_size=47, metric=euclidean, n_neighbors=1, p=2, weights=distance;, score=(train=1.000, test=0.706) total time=   2.6s
# [CV 3/3] END algorithm=kd_tree, leaf_size=47, metric=euclidean, n_neighbors=1, p=2, weights=distance;, score=(train=1.000, test=0.709) total time=   1.9s
# [CV 1/3] END algorithm=brute, leaf_size=38, metric=manhattan, n_neighbors=11, p=2, weights=uniform;, score=(train=0.953, test=0.889) total time=   3.0s
# [CV 3/3] END algorithm=brute, leaf_size=38, metric=manhattan, n_neighbors=11, p=2, weights=uniform;, score=(train=0.956, test=0.893) total time=   3.2s
# [CV 2/3] END algorithm=brute, leaf_size=38, metric=manhattan, n_neighbors=11, p=2, weights=uniform;, score=(train=0.955, test=0.891) total time=   3.2s
# [CV 1/3] END algorithm=auto, leaf_size=48, metric=euclidean, n_neighbors=4, p=1, weights=distance;, score=(train=1.000, test=0.847) total time=   0.3s
# [CV 2/3] END algorithm=auto, leaf_size=48, metric=euclidean, n_neighbors=4, p=1, weights=distance;, score=(train=1.000, test=0.857) total time=   0.3s
# [CV 3/3] END algorithm=auto, leaf_size=48, metric=euclidean, n_neighbors=4, p=1, weights=distance;, score=(train=1.000, test=0.849) total time=   0.4s
# [CV 1/3] END algorithm=kd_tree, leaf_size=34, metric=minkowski, n_neighbors=10, p=2, weights=distance;, score=(train=1.000, test=0.902) total time=   3.3s
# [CV 3/3] END algorithm=kd_tree, leaf_size=34, metric=minkowski, n_neighbors=10, p=2, weights=distance;, score=(train=1.000, test=0.899) total time=   3.9s
# [CV 2/3] END algorithm=kd_tree, leaf_size=34, metric=minkowski, n_neighbors=10, p=2, weights=distance;, score=(train=1.000, test=0.900) total time=   4.1s
# [CV 1/3] END algorithm=brute, leaf_size=12, metric=minkowski, n_neighbors=19, p=1, weights=uniform;, score=(train=0.945, test=0.910) total time=   3.1s
# [CV 2/3] END algorithm=brute, leaf_size=12, metric=minkowski, n_neighbors=19, p=1, weights=uniform;, score=(train=0.948, test=0.904) total time=   3.3s
# [CV 1/3] END algorithm=kd_tree, leaf_size=18, metric=euclidean, n_neighbors=2, p=2, weights=distance;, score=(train=1.000, test=0.781) total time=   2.4s
# [CV 2/3] END algorithm=kd_tree, leaf_size=18, metric=euclidean, n_neighbors=2, p=2, weights=distance;, score=(train=1.000, test=0.791) total time=   2.7s
# [CV 3/3] END algorithm=brute, leaf_size=12, metric=minkowski, n_neighbors=19, p=1, weights=uniform;, score=(train=0.952, test=0.909) total time=   3.4s
# [CV 3/3] END algorithm=kd_tree, leaf_size=18, metric=euclidean, n_neighbors=2, p=2, weights=distance;, score=(train=1.000, test=0.784) total time=   2.5s
# ----------
# iter: 1
# n_candidates: 5
# n_resources: 42186
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV 1/3] END algorithm=auto, leaf_size=48, metric=euclidean, n_neighbors=4, p=1, weights=distance;, score=(train=1.000, test=0.860) total time=   1.1s
# [CV 3/3] END algorithm=auto, leaf_size=48, metric=euclidean, n_neighbors=4, p=1, weights=distance;, score=(train=1.000, test=0.854) total time=   1.6s
# [CV 2/3] END algorithm=auto, leaf_size=48, metric=euclidean, n_neighbors=4, p=1, weights=distance;, score=(train=1.000, test=0.868) total time=   0.8s
# [CV 2/3] END algorithm=kd_tree, leaf_size=34, metric=minkowski, n_neighbors=10, p=2, weights=distance;, score=(train=1.000, test=0.912) total time=  11.2s
# [CV 1/3] END algorithm=kd_tree, leaf_size=34, metric=minkowski, n_neighbors=10, p=2, weights=distance;, score=(train=1.000, test=0.907) total time=  11.4s
# [CV 3/3] END algorithm=kd_tree, leaf_size=34, metric=minkowski, n_neighbors=10, p=2, weights=distance;, score=(train=1.000, test=0.902) total time=  12.1s
# [CV 1/3] END algorithm=auto, leaf_size=48, metric=euclidean, n_neighbors=19, p=1, weights=uniform;, score=(train=0.952, test=0.922) total time=   1.1s
# [CV 1/3] END algorithm=brute, leaf_size=38, metric=manhattan, n_neighbors=11, p=2, weights=uniform;, score=(train=0.956, test=0.899) total time=  12.8s
# [CV 2/3] END algorithm=auto, leaf_size=48, metric=euclidean, n_neighbors=19, p=1, weights=uniform;, score=(train=0.954, test=0.923) total time=   0.9s
# [CV 3/3] END algorithm=brute, leaf_size=38, metric=manhattan, n_neighbors=11, p=2, weights=uniform;, score=(train=0.959, test=0.894) total time=  13.6s
# [CV 2/3] END algorithm=brute, leaf_size=38, metric=manhattan, n_neighbors=11, p=2, weights=uniform;, score=(train=0.957, test=0.900) total time=  13.6s
# [CV 3/3] END algorithm=auto, leaf_size=48, metric=euclidean, n_neighbors=19, p=1, weights=uniform;, score=(train=0.955, test=0.921) total time=   0.9s
# [CV 1/3] END algorithm=brute, leaf_size=12, metric=minkowski, n_neighbors=19, p=1, weights=uniform;, score=(train=0.950, test=0.914) total time=  13.1s
# [CV 2/3] END algorithm=brute, leaf_size=12, metric=minkowski, n_neighbors=19, p=1, weights=uniform;, score=(train=0.952, test=0.916) total time=  13.4s
# [CV 3/3] END algorithm=brute, leaf_size=12, metric=minkowski, n_neighbors=19, p=1, weights=uniform;, score=(train=0.953, test=0.914) total time=  10.6s
# ----------
# iter: 2
# n_candidates: 3
# n_resources: 84372
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# [CV 1/3] END algorithm=auto, leaf_size=48, metric=euclidean, n_neighbors=19, p=1, weights=uniform;, score=(train=0.953, test=0.927) total time=   4.3s
# [CV 2/3] END algorithm=auto, leaf_size=48, metric=euclidean, n_neighbors=19, p=1, weights=uniform;, score=(train=0.955, test=0.928) total time=   3.3s
# [CV 3/3] END algorithm=auto, leaf_size=48, metric=euclidean, n_neighbors=19, p=1, weights=uniform;, score=(train=0.955, test=0.926) total time=   4.1s
# [CV 3/3] END algorithm=brute, leaf_size=12, metric=minkowski, n_neighbors=19, p=1, weights=uniform;, score=(train=0.954, test=0.924) total time=  45.2s
# [CV 1/3] END algorithm=brute, leaf_size=12, metric=minkowski, n_neighbors=19, p=1, weights=uniform;, score=(train=0.953, test=0.922) total time=  46.3s
# [CV 2/3] END algorithm=brute, leaf_size=12, metric=minkowski, n_neighbors=19, p=1, weights=uniform;, score=(train=0.954, test=0.923) total time=  45.5s
# [CV 3/3] END algorithm=kd_tree, leaf_size=34, metric=minkowski, n_neighbors=10, p=2, weights=distance;, score=(train=1.000, test=0.908) total time=  50.6s
# [CV 1/3] END algorithm=kd_tree, leaf_size=34, metric=minkowski, n_neighbors=10, p=2, weights=distance;, score=(train=1.000, test=0.912) total time=  51.1s
# [CV 2/3] END algorithm=kd_tree, leaf_size=34, metric=minkowski, n_neighbors=10, p=2, weights=distance;, score=(train=1.000, test=0.913) total time=  49.2s
# ----------
# iter: 3
# n_candidates: 2
# n_resources: 168744
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# [CV 2/3] END algorithm=auto, leaf_size=48, metric=euclidean, n_neighbors=19, p=1, weights=uniform;, score=(train=0.957, test=0.930) total time=  16.3s
# [CV 3/3] END algorithm=auto, leaf_size=48, metric=euclidean, n_neighbors=19, p=1, weights=uniform;, score=(train=0.956, test=0.929) total time=  15.8s
# [CV 1/3] END algorithm=auto, leaf_size=48, metric=euclidean, n_neighbors=19, p=1, weights=uniform;, score=(train=0.955, test=0.931) total time=  16.6s
# [CV 1/3] END algorithm=brute, leaf_size=12, metric=minkowski, n_neighbors=19, p=1, weights=uniform;, score=(train=0.954, test=0.927) total time= 2.3min
# [CV 2/3] END algorithm=brute, leaf_size=12, metric=minkowski, n_neighbors=19, p=1, weights=uniform;, score=(train=0.956, test=0.928) total time= 2.3min
# [CV 3/3] END algorithm=brute, leaf_size=12, metric=minkowski, n_neighbors=19, p=1, weights=uniform;, score=(train=0.956, test=0.927) total time= 2.3min
# knn best score: 0.9299
#
# Best Hyperparameters Found:
# {'algorithm': 'auto', 'leaf_size': 48, 'metric': 'euclidean', 'n_neighbors': 19, 'p': 1, 'weights': 'uniform'}
# ========================================
# gbdt
# ========================================
# n_iterations: 4
# n_required_iterations: 4
# n_possible_iterations: 4
# min_resources_: 21093
# max_resources_: 202500
# aggressive_elimination: False
# factor: 2
# ----------
# iter: 0
# n_candidates: 9
# n_resources: 21093
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END learning_rate=0.010994335574766204, max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=291, subsample=0.996884623716487;, score=(train=0.953, test=0.943) total time=   1.9s
# [CV 2/3] END learning_rate=0.010994335574766204, max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=291, subsample=0.996884623716487;, score=(train=0.956, test=0.944) total time=   2.1s
# [CV 3/3] END learning_rate=0.010994335574766204, max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=3, n_estimators=291, subsample=0.996884623716487;, score=(train=0.956, test=0.951) total time=   2.0s
# [CV 1/3] END learning_rate=0.17177621112338382, max_depth=4, max_features=log2, min_samples_leaf=12, min_samples_split=18, n_estimators=574, subsample=0.8447411578889518;, score=(train=0.994, test=0.954) total time=   4.0s
# [CV 2/3] END learning_rate=0.17177621112338382, max_depth=4, max_features=log2, min_samples_leaf=12, min_samples_split=18, n_estimators=574, subsample=0.8447411578889518;, score=(train=0.995, test=0.948) total time=   3.7s
# [CV 3/3] END learning_rate=0.17177621112338382, max_depth=4, max_features=log2, min_samples_leaf=12, min_samples_split=18, n_estimators=574, subsample=0.8447411578889518;, score=(train=0.994, test=0.955) total time=   3.7s
# [CV 1/3] END learning_rate=0.05611516415334506, max_depth=7, max_features=None, min_samples_leaf=11, min_samples_split=9, n_estimators=800, subsample=0.8387400631785948;, score=(train=1.000, test=0.952) total time=  43.1s
# /Users/haukesteffen/dev/TabularShenanigans/.venv/lib/python3.13/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV 3/3] END learning_rate=0.05611516415334506, max_depth=7, max_features=None, min_samples_leaf=11, min_samples_split=9, n_estimators=800, subsample=0.8387400631785948;, score=(train=1.000, test=0.953) total time=  50.7s
# [CV 2/3] END learning_rate=0.05611516415334506, max_depth=7, max_features=None, min_samples_leaf=11, min_samples_split=9, n_estimators=800, subsample=0.8387400631785948;, score=(train=1.000, test=0.951) total time=  51.1s
# [CV 1/3] END learning_rate=0.01901024531987036, max_depth=6, max_features=None, min_samples_leaf=15, min_samples_split=13, n_estimators=666, subsample=0.9932923543227152;, score=(train=0.988, test=0.953) total time=  42.9s
# [CV 2/3] END learning_rate=0.01901024531987036, max_depth=6, max_features=None, min_samples_leaf=15, min_samples_split=13, n_estimators=666, subsample=0.9932923543227152;, score=(train=0.991, test=0.954) total time=  43.0s
# [CV 1/3] END learning_rate=0.7663082680255849, max_depth=8, max_features=log2, min_samples_leaf=9, min_samples_split=3, n_estimators=439, subsample=0.6964101864104046;, score=(train=0.697, test=0.673) total time=   5.3s
# [CV 2/3] END learning_rate=0.08580760619921299, max_depth=7, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=266, subsample=0.6053059844639466;, score=(train=1.000, test=0.951) total time=  12.5s
# [CV 1/3] END learning_rate=0.08580760619921299, max_depth=7, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=266, subsample=0.6053059844639466;, score=(train=0.999, test=0.952) total time=  12.9s
# [CV 3/3] END learning_rate=0.08580760619921299, max_depth=7, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=266, subsample=0.6053059844639466;, score=(train=1.000, test=0.954) total time=  12.8s
# [CV 2/3] END learning_rate=0.7663082680255849, max_depth=8, max_features=log2, min_samples_leaf=9, min_samples_split=3, n_estimators=439, subsample=0.6964101864104046;, score=(train=0.698, test=0.662) total time=   4.7s
# [CV 1/3] END learning_rate=0.23255572624036783, max_depth=6, max_features=sqrt, min_samples_leaf=8, min_samples_split=16, n_estimators=134, subsample=0.9637281608315128;, score=(train=0.996, test=0.952) total time=   1.8s
# [CV 2/3] END learning_rate=0.23255572624036783, max_depth=6, max_features=sqrt, min_samples_leaf=8, min_samples_split=16, n_estimators=134, subsample=0.9637281608315128;, score=(train=0.998, test=0.948) total time=   1.9s
# [CV 3/3] END learning_rate=0.23255572624036783, max_depth=6, max_features=sqrt, min_samples_leaf=8, min_samples_split=16, n_estimators=134, subsample=0.9637281608315128;, score=(train=0.997, test=0.955) total time=   1.7s
# [CV 3/3] END learning_rate=0.07792297153882995, max_depth=9, max_features=None, min_samples_leaf=11, min_samples_split=5, n_estimators=971, subsample=0.8832290311184181;, score=(train=1.000, test=0.949) total time= 1.2min
# [CV 3/3] END learning_rate=0.7663082680255849, max_depth=8, max_features=log2, min_samples_leaf=9, min_samples_split=3, n_estimators=439, subsample=0.6964101864104046;, score=(train=0.696, test=0.692) total time=   5.8s
# [CV 3/3] END learning_rate=0.032927591344236166, max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=871, subsample=0.6739417822102108;, score=(train=0.995, test=0.960) total time=   6.0s
# [CV 1/3] END learning_rate=0.032927591344236166, max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=871, subsample=0.6739417822102108;, score=(train=0.995, test=0.956) total time=   7.0s
# [CV 2/3] END learning_rate=0.032927591344236166, max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=871, subsample=0.6739417822102108;, score=(train=0.996, test=0.952) total time=   6.8s
# [CV 1/3] END learning_rate=0.07792297153882995, max_depth=9, max_features=None, min_samples_leaf=11, min_samples_split=5, n_estimators=971, subsample=0.8832290311184181;, score=(train=1.000, test=0.949) total time= 1.3min
# [CV 3/3] END learning_rate=0.01901024531987036, max_depth=6, max_features=None, min_samples_leaf=15, min_samples_split=13, n_estimators=666, subsample=0.9932923543227152;, score=(train=0.989, test=0.959) total time=  36.4s
# [CV 2/3] END learning_rate=0.07792297153882995, max_depth=9, max_features=None, min_samples_leaf=11, min_samples_split=5, n_estimators=971, subsample=0.8832290311184181;, score=(train=1.000, test=0.949) total time= 1.3min
# ----------
# iter: 1
# n_candidates: 5
# n_resources: 42186
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV 2/3] END learning_rate=0.17177621112338382, max_depth=4, max_features=log2, min_samples_leaf=12, min_samples_split=18, n_estimators=574, subsample=0.8447411578889518;, score=(train=0.987, test=0.957) total time=   5.8s
# [CV 1/3] END learning_rate=0.17177621112338382, max_depth=4, max_features=log2, min_samples_leaf=12, min_samples_split=18, n_estimators=574, subsample=0.8447411578889518;, score=(train=0.986, test=0.959) total time=   6.0s
# [CV 3/3] END learning_rate=0.17177621112338382, max_depth=4, max_features=log2, min_samples_leaf=12, min_samples_split=18, n_estimators=574, subsample=0.8447411578889518;, score=(train=0.986, test=0.956) total time=   8.1s
# [CV 1/3] END learning_rate=0.08580760619921299, max_depth=7, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=266, subsample=0.6053059844639466;, score=(train=0.996, test=0.957) total time=  23.4s
# [CV 2/3] END learning_rate=0.08580760619921299, max_depth=7, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=266, subsample=0.6053059844639466;, score=(train=0.997, test=0.957) total time=  27.4s
# [CV 3/3] END learning_rate=0.08580760619921299, max_depth=7, max_features=None, min_samples_leaf=7, min_samples_split=10, n_estimators=266, subsample=0.6053059844639466;, score=(train=0.996, test=0.957) total time=  26.0s
# [CV 1/3] END learning_rate=0.032927591344236166, max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=871, subsample=0.6739417822102108;, score=(train=0.987, test=0.959) total time=  12.7s
# [CV 2/3] END learning_rate=0.032927591344236166, max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=871, subsample=0.6739417822102108;, score=(train=0.988, test=0.959) total time=  12.3s
# [CV 3/3] END learning_rate=0.032927591344236166, max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=871, subsample=0.6739417822102108;, score=(train=0.988, test=0.959) total time=  11.9s
# [CV 2/3] END learning_rate=0.05611516415334506, max_depth=7, max_features=None, min_samples_leaf=11, min_samples_split=9, n_estimators=800, subsample=0.8387400631785948;, score=(train=1.000, test=0.958) total time= 1.4min
# [CV 1/3] END learning_rate=0.05611516415334506, max_depth=7, max_features=None, min_samples_leaf=11, min_samples_split=9, n_estimators=800, subsample=0.8387400631785948;, score=(train=1.000, test=0.958) total time= 1.4min
# [CV 1/3] END learning_rate=0.01901024531987036, max_depth=6, max_features=None, min_samples_leaf=15, min_samples_split=13, n_estimators=666, subsample=0.9932923543227152;, score=(train=0.982, test=0.958) total time= 1.3min
# [CV 2/3] END learning_rate=0.01901024531987036, max_depth=6, max_features=None, min_samples_leaf=15, min_samples_split=13, n_estimators=666, subsample=0.9932923543227152;, score=(train=0.984, test=0.958) total time= 1.3min
# [CV 3/3] END learning_rate=0.05611516415334506, max_depth=7, max_features=None, min_samples_leaf=11, min_samples_split=9, n_estimators=800, subsample=0.8387400631785948;, score=(train=1.000, test=0.958) total time= 1.5min
# [CV 3/3] END learning_rate=0.01901024531987036, max_depth=6, max_features=None, min_samples_leaf=15, min_samples_split=13, n_estimators=666, subsample=0.9932923543227152;, score=(train=0.983, test=0.959) total time= 1.2min
# ----------
# iter: 2
# n_candidates: 3
# n_resources: 84372
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# [CV 2/3] END learning_rate=0.032927591344236166, max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=871, subsample=0.6739417822102108;, score=(train=0.980, test=0.961) total time=  26.7s
# [CV 1/3] END learning_rate=0.032927591344236166, max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=871, subsample=0.6739417822102108;, score=(train=0.979, test=0.961) total time=  27.9s
# [CV 3/3] END learning_rate=0.032927591344236166, max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=871, subsample=0.6739417822102108;, score=(train=0.980, test=0.961) total time=  24.3s
# [CV 1/3] END learning_rate=0.01901024531987036, max_depth=6, max_features=None, min_samples_leaf=15, min_samples_split=13, n_estimators=666, subsample=0.9932923543227152;, score=(train=0.976, test=0.960) total time= 2.5min
# [CV 2/3] END learning_rate=0.01901024531987036, max_depth=6, max_features=None, min_samples_leaf=15, min_samples_split=13, n_estimators=666, subsample=0.9932923543227152;, score=(train=0.978, test=0.960) total time= 2.5min
# [CV 3/3] END learning_rate=0.01901024531987036, max_depth=6, max_features=None, min_samples_leaf=15, min_samples_split=13, n_estimators=666, subsample=0.9932923543227152;, score=(train=0.977, test=0.960) total time= 2.5min
# [CV 3/3] END learning_rate=0.05611516415334506, max_depth=7, max_features=None, min_samples_leaf=11, min_samples_split=9, n_estimators=800, subsample=0.8387400631785948;, score=(train=0.998, test=0.961) total time= 2.7min
# [CV 1/3] END learning_rate=0.05611516415334506, max_depth=7, max_features=None, min_samples_leaf=11, min_samples_split=9, n_estimators=800, subsample=0.8387400631785948;, score=(train=0.998, test=0.962) total time= 2.7min
# [CV 2/3] END learning_rate=0.05611516415334506, max_depth=7, max_features=None, min_samples_leaf=11, min_samples_split=9, n_estimators=800, subsample=0.8387400631785948;, score=(train=0.998, test=0.961) total time= 2.9min
# ----------
# iter: 3
# n_candidates: 2
# n_resources: 168744
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# [CV 1/3] END learning_rate=0.032927591344236166, max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=871, subsample=0.6739417822102108;, score=(train=0.974, test=0.964) total time=  41.5s
# [CV 3/3] END learning_rate=0.032927591344236166, max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=871, subsample=0.6739417822102108;, score=(train=0.975, test=0.963) total time=  41.4s
# [CV 2/3] END learning_rate=0.032927591344236166, max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=871, subsample=0.6739417822102108;, score=(train=0.975, test=0.962) total time=  42.7s
# [CV 2/3] END learning_rate=0.05611516415334506, max_depth=7, max_features=None, min_samples_leaf=11, min_samples_split=9, n_estimators=800, subsample=0.8387400631785948;, score=(train=0.993, test=0.965) total time= 5.0min
# [CV 3/3] END learning_rate=0.05611516415334506, max_depth=7, max_features=None, min_samples_leaf=11, min_samples_split=9, n_estimators=800, subsample=0.8387400631785948;, score=(train=0.992, test=0.965) total time= 5.0min
# [CV 1/3] END learning_rate=0.05611516415334506, max_depth=7, max_features=None, min_samples_leaf=11, min_samples_split=9, n_estimators=800, subsample=0.8387400631785948;, score=(train=0.992, test=0.966) total time= 5.1min
# gbdt best score: 0.9654
#
# Best Hyperparameters Found:
# {'learning_rate': 0.05611516415334506, 'max_depth': 7, 'max_features': None, 'min_samples_leaf': 11, 'min_samples_split': 9, 'n_estimators': 800, 'subsample': 0.8387400631785948}

# %%
print("Validation ROC AUC scores:\n" + "-" * 40)

for name, model in best_models.items():
    val_preds = model.predict_proba(X_val)[:, 1]
    auc = roc_auc_score(y_val, val_preds)
    print(f"{name:<10} : {auc:.4f}")
# Out:
# Validation ROC AUC scores:
# ----------------------------------------
# logreg     : 0.9379
# mlp        : 0.9621
# linear     : 0.9358
# knn        : 0.9368
# gbdt       : 0.9704

# %%
best_params = {name: model.get_params() for name, model in best_models.items()}

with open(config.data_path / "best_params.json", "w") as f:
    json.dump(best_params, f, indent=4)
